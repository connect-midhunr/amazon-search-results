# %% [markdown]
# # Amazon Web Scraping

# %% [markdown]
# ## Introduction

# %% [markdown]
# The goal of this project is to scrape the Amazon website to get details of products based on the search results.

# %% [markdown]
# ## Import Libraries

# %% [markdown]
# Libraries required for the project are imported.

# %%
# For webscraping
from bs4 import BeautifulSoup
# Chrome driver
from selenium import webdriver
# Chrome driver manager
from webdriver_manager.chrome import ChromeDriverManager
# For current data and time
from datetime import datetime
# For writing results to CSV file
import csv

# %% [markdown]
# ## Initialize Webdriver

# %% [markdown]
# Web driver for Google Chrome is initialized since the scraping will be done on Google Chrome.

# %%
# Initialize webdriver for chrome
driver = webdriver.Chrome(ChromeDriverManager().install())
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 96.0.4664
# Get LATEST chromedriver version for 96.0.4664 google-chrome
# Driver [C:\Users\iammi\.wdm\drivers\chromedriver\win32\96.0.4664.45\chromedriver.exe] found in cache
# C:\Users\iammi\AppData\Local\Temp/ipykernel_19152/1566263371.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install())

# %% [markdown]
# ## Extract Data Collection

# %% [markdown]
# Below steps are followed for extracting data from the website.

# %%
url = 'https://www.amazon.in/s?k=iphone+13'

# Navigate to the URL
driver.get(url)

# %%
# Initialize BeautifulSoup
soup = BeautifulSoup(driver.page_source, 'html.parser')

# %%
# Get product data
product_data = soup.find_all('div', {'data-component-type': 's-search-result'})
# No. of products whose data extracted
len(product_data)
# Out:
# 18

# %% [markdown]
# ## Prototype Product Information

# %% [markdown]
# Since the identification of collection of records has been completed, the next step is to prototype the extraction of information from a single product item.

# %%
# Consider a single record
product = product_data[0]

# %%
# Extract product name
product_name = product.h2.a.text.strip()
print(product_name)
# Out:
# Apple iPhone 13 Mini (128GB) - Blue

# %%
# Extract product link
product_link = 'https://www.amazon.in' + product.h2.a.get('href')
print(product_link)
# Out:
# https://www.amazon.in/gp/slredirect/picassoRedirect.html/ref=pa_sp_atf_aps_sr_pg1_1?ie=UTF8&adId=A08694961VBUR5DCN1K0W&url=%2FApple-iPhone-13-Mini-128GB%2Fdp%2FB09G99NBNQ%2Fref%3Dsr_1_1_sspa%3Fkeywords%3Diphone%2B13%26qid%3D1640945983%26sr%3D8-1-spons%26psc%3D1&qualifier=1640945983&id=176615068607060&widgetName=sp_atf

# %%
# Extract product price
product_price = product.find('span', 'a-price-whole').text
print(product_price)
# Out:
# 69,900

# %%
# Extract product ratings
product_ratings = product.find('span', 'a-icon-alt').text.strip(' out of 5 stars')
print(product_ratings)
# Out:
# 4.4

# %%
# Extract no. of reviews
product_num_of_reviews = product.find('span', 'a-size-base').text
print(product_num_of_reviews)
# Out:
# 280

# %% [markdown]
# ## Formulate a Function for Extracting Product Information

# %% [markdown]
# A function is created for extracting information related to a product.

# %%
# Function for extracting product data
def extract_data(product):
    name = product.h2.a.text.strip()
    price = product.find('span', 'a-price-whole').text
    ratings = product.find('span', 'a-icon-alt').text.strip(' out of 5 stars')
    num_of_reviews = product.find('span', 'a-size-base').text
    link = 'https://www.amazon.in' + product.h2.a.get('href')
    
    info = (name, price, ratings, num_of_reviews, link)
    return info

# %%
# Testing extract_data function
print(extract_data(product_data[1]))
# Out:
# ('New Apple iPhone 12 Mini (256GB) - (Product) RED', '₹64,999', '4.', '6,218', 'https://www.amazon.in/gp/slredirect/picassoRedirect.html/ref=pa_sp_atf_aps_sr_pg1_1?ie=UTF8&adId=A03142682ROKNU8C01UJ5&url=%2FNew-Apple-iPhone-Mini-256GB%2Fdp%2FB08L5WKDFF%2Fref%3Dsr_1_2_sspa%3Fkeywords%3Diphone%2B13%26qid%3D1640945983%26sr%3D8-2-spons%26psc%3D1&qualifier=1640945983&id=176615068607060&widgetName=sp_atf')

# %% [markdown]
# The function is working as intended for a single product item. Now the working of this function for all the products needs to be checked.

# %%
# For storing multiple product information
product_info = []

# Get product data
product_data = soup.find_all('div', {'data-component-type': 's-search-result'})

# Extract information of each product and store them in product_info
for product in product_data:
    product_info.append(extract_data(product))

# Print product information
for product in product_info:
    for info in product:
        print(info)
    print()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19152/3338839418.py in <module>
#       7 # Extract information of each product and store them in product_info
#       8 for product in product_data:
# ----> 9     product_info.append(extract_data(product))
#      10
#      11 # Print product information
#
# ~\AppData\Local\Temp/ipykernel_19152/3047507208.py in extract_data(product)
#       3     name = product.h2.a.text.strip()
#       4     price = product.find('span', 'a-price').find('span', 'a-offscreen').text
# ----> 5     ratings = product.find('span', 'a-icon-alt').text.strip(' out of 5 stars')
#       6     num_of_reviews = product.find('span', 'a-size-base').text
#       7     link = 'https://www.amazon.in' + product.h2.a.get('href')
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %% [markdown]
# An exception has occured since ratings and reviews of a product is not available.

# %% [markdown]
# ## Exception Handling

# %% [markdown]
# Since there are more products with no ratings and reviews, exception handling must be carried out such that the program should not crash while running.

# %%
# Function for extracting product data with exception handling
def extract_data(product):
    
    try:
        name = product.h2.a.text.strip()
        price = product.find('span', 'a-price-whole').text
        link = 'https://www.amazon.in' + product.h2.a.get('href')
    except:
        return
    
    try: 
        ratings = product.find('span', 'a-icon-alt').text.strip(' out of 5 stars')
        num_of_reviews = product.find('span', 'a-size-base').text
    except:
        ratings = ''
        num_of_reviews = ''
    
    info = (name, price, ratings, num_of_reviews, link)
    return info

# %% [markdown]
# Testing of this function is carried out.

# %%
# Extract information of each product and store them in a list
for product in product_data:
    info = extract_data(product)
    # Product info is added to list only if info is not empty
    if info:
        product_info.append(info)

# Print product information
for product in product_info:
    for info in product:
        print(info)
    print()
# Out:
# Apple iPhone 13 Mini (128GB) - Blue
# ₹69,900
# 4.4
# 280
# https://www.amazon.in/gp/slredirect/picassoRedirect.html/ref=pa_sp_atf_aps_sr_pg1_1?ie=UTF8&adId=A08694961VBUR5DCN1K0W&url=%2FApple-iPhone-13-Mini-128GB%2Fdp%2FB09G99NBNQ%2Fref%3Dsr_1_1_sspa%3Fkeywords%3Diphone%2B13%26qid%3D1640945983%26sr%3D8-1-spons%26psc%3D1&qualifier=1640945983&id=176615068607060&widgetName=sp_atf
#
# New Apple iPhone 12 Mini (256GB) - (Product) RED
# ₹64,999
# 4.
# 6,218
# https://www.amazon.in/gp/slredirect/picassoRedirect.html/ref=pa_sp_atf_aps_sr_pg1_1?ie=UTF8&adId=A03142682ROKNU8C01UJ5&url=%2FNew-Apple-iPhone-Mini-256GB%2Fdp%2FB08L5WKDFF%2Fref%3Dsr_1_2_sspa%3Fkeywords%3Diphone%2B13%26qid%3D1640945983%26sr%3D8-2-spons%26psc%3D1&qualifier=1640945983&id=176615068607060&widgetName=sp_atf
#
# Apple iPhone 13 (256GB) - (Product) RED
# ₹89,900
# 4.6
# 553
# https://www.amazon.in/Apple-iPhone-13-256GB-Product/dp/B09G9HDN4Q/ref=sr_1_3?keywords=iphone+13&qid=1640945983&sr=8-3
#
# Apple iPhone 13 Mini (128GB) - (Product) RED
# ₹69,900
# 4.4
# 280
# https://www.amazon.in/Apple-iPhone-13-Mini-128GB/dp/B09G99WQVX/ref=sr_1_4?keywords=iphone+13&qid=1640945983&sr=8-4
#
# Apple iPhone 13 Mini (128GB) - Blue
# ₹69,900
# 4.4
# 280
# https://www.amazon.in/gp/slredirect/picassoRedirect.html/ref=pa_sp_atf_aps_sr_pg1_1?ie=UTF8&adId=A08694961VBUR5DCN1K0W&url=%2FApple-iPhone-13-Mini-128GB%2Fdp%2FB09G99NBNQ%2Fref%3Dsr_1_1_sspa%3Fkeywords%3Diphone%2B13%26qid%3D1640945983%26sr%3D8-1-spons%26psc%3D1&qualifier=1640945983&id=176615068607060&widgetName=sp_atf
#
# New Apple iPhone 12 Mini (256GB) - (Product) RED
# ₹64,999
# 4.
# 6,218
# https://www.amazon.in/gp/slredirect/picassoRedirect.html/ref=pa_sp_atf_aps_sr_pg1_1?ie=UTF8&adId=A03142682ROKNU8C01UJ5&url=%2FNew-Apple-iPhone-Mini-256GB%2Fdp%2FB08L5WKDFF%2Fref%3Dsr_1_2_sspa%3Fkeywords%3Diphone%2B13%26qid%3D1640945983%26sr%3D8-2-spons%26psc%3D1&qualifier=1640945983&id=176615068607060&widgetName=sp_atf
#
# Apple iPhone 13 (256GB) - (Product) RED
# ₹89,900
# 4.6
# 553
# https://www.amazon.in/Apple-iPhone-13-256GB-Product/dp/B09G9HDN4Q/ref=sr_1_3?keywords=iphone+13&qid=1640945983&sr=8-3
#
# Apple iPhone 13 Mini (128GB) - (Product) RED
# ₹69,900
# 4.4
# 280
# https://www.amazon.in/Apple-iPhone-13-Mini-128GB/dp/B09G99WQVX/ref=sr_1_4?keywords=iphone+13&qid=1640945983&sr=8-4
#
# Mobirush iPhone 13 Pro Max Kickstand Hybrid Desk Stand Back Case Cover for iPhone 13 Pro Max - Black
# ₹299
#
#
# https://www.amazon.in/Mobirush-iPhone-13-Pro-Max/dp/B09M8RTWD6/ref=sr_1_5?keywords=iphone+13&qid=1640945983&sr=8-5
#
# Apple iPhone 13 Pro (512GB) - Sierra Blue
# ₹1,49,900
# 4.7
# 177
# https://www.amazon.in/Apple-iPhone-13-Pro-512GB/dp/B09G9KQGJJ/ref=sr_1_6?keywords=iphone+13&qid=1640945983&sr=8-6
#
# Mobirush (Camera Protection) Matte Case Cover for iPhone 13 Pro - Red
# ₹299
#
#
# https://www.amazon.in/Mobirush-Protection-iPhone-13-Pro/dp/B09KM8LXP3/ref=sr_1_7?keywords=iphone+13&qid=1640945983&sr=8-7
#
# Jacure Design for iPhone 13 Mini Tempered Glass Back Side Rear Protector Proper Fit Bubble Free Case Friendly Easy Installation - Black
# ₹499
#
#
# https://www.amazon.in/Jacure-iPhone-13-Mini-Installation/dp/B09P58PHCP/ref=sr_1_8?keywords=iphone+13&qid=1640945983&sr=8-8
#
# New Apple iPhone 12 Pro Max (256GB) - Gold with Apple 20W USB-C Power Adapter
# ₹1,31,749
# 4.7
# 1,466
# https://www.amazon.in/New-Apple-iPhone-Pro-256GB/dp/B08Z72BSJJ/ref=sr_1_9?keywords=iphone+13&qid=1640945983&sr=8-9
#
# Cascov (Camera Protection) Matte Case Cover for iPhone 13 Pro Max - Black
# ₹299
#
#
# https://www.amazon.in/Cascov-Protection-iPhone-Pro-Max/dp/B09N9HPK91/ref=sr_1_10?keywords=iphone+13&qid=1640945983&sr=8-10
#
# Cascov (Camera Protection) Matte Case Cover for iPhone 13 Pro Max - Dark Green
# ₹299
#
#
# https://www.amazon.in/Cascov-Protection-iPhone-Pro-Max/dp/B09N9KY9GG/ref=sr_1_11?keywords=iphone+13&qid=1640945983&sr=8-11
#
# CellKraft Back Cover for i Phone 13 Pro Max Compatible (6.7 Inch) Rainbow Soft Liquid Silicone TPU Case Shockproof | Camera Protection | (Multi-Coloured) | (Multi Colour3)
# ₹399
# .0
# 3
# https://www.amazon.in/CellKraft-Compatible-Shockproof-Protection-Multi-Coloured/dp/B09LMTFQDT/ref=sr_1_12?keywords=iphone+13&qid=1640945983&sr=8-12
#
# Mobirush (Camera Protection) Matte Case Cover for iPhone 13 Mini - Blue
# ₹299
# .0
# 1
# https://www.amazon.in/Mobirush-Protection-iPhone-13-Mini/dp/B09KM5FQ6H/ref=sr_1_13?keywords=iphone+13&qid=1640945983&sr=8-13
#
# Glaslux (Camera Protection) Matte Case Cover for iPhone 13 Mini - Black
# ₹299
# .0
# 1
# https://www.amazon.in/Glaslux-Protection-iPhone-13-Mini/dp/B09KNMGGPP/ref=sr_1_14?keywords=iphone+13&qid=1640945983&sr=8-14
#
# Cascov (Camera Protection) Matte Case Cover for iPhone 13 Pro - Black
# ₹299
#
#
# https://www.amazon.in/Cascov-Protection-iPhone-13-Pro/dp/B09N9JM14V/ref=sr_1_15?keywords=iphone+13&qid=1640945983&sr=8-15
#
# Glaslux iPhone 13 Kickstand Hybrid Desk Stand Back Case Cover for iPhone 13 - Black
# ₹299
#
#
# https://www.amazon.in/Glaslux-iPhone-13-Kickstand-Hybrid/dp/B09M8WH4GC/ref=sr_1_16?keywords=iphone+13&qid=1640945983&sr=8-16
#
# Nillkin Case for Apple iPhone 13 Pro (6.1" Inch) CamShield Silky Soft Liquid Silicon + PC Finish Camera Slider Inner Microfiber Black
# ₹1,314
#
#
# https://www.amazon.in/Nillkin-iPhone-CamShield-Silicon-Microfiber/dp/B09HXZF2DT/ref=sr_1_17?keywords=iphone+13&qid=1640945983&sr=8-17
#
# OJOS Compatible for iPhone 13 Pro/iPhone 13 Pro Max Camera Lens Protector Tempered Glass Screen Protector Case Friendly for iPhone 13Pro / 13 ProMax 2021 (Clear)
# ₹399
#
#
# https://www.amazon.in/OJOS-Compatible-Protector-Tempered-Friendly/dp/B09N3JDQS7/ref=sr_1_18?keywords=iphone+13&qid=1640945983&sr=8-18

# %% [markdown]
# The function is found to be working fine.

# %% [markdown]
# ## Formulate a Function for Getting URL for given Search Input

# %% [markdown]
# The URL of the search result page depends directly on the search input given by the user. Thus a function is created to generate the required URL.

# %%
# Function for generating URL based on user search input
def get_url(search_input):
    search_input_mod = search_input.replace(' ', '+')
    url = 'https://www.amazon.in/s?k=' + search_input_mod
    return url

# %% [markdown]
# ## Formulate a Function for Creating Soup for All Pages

# %% [markdown]
# The search result in Amazon extends upto 20 pages. The code needs to be written in order to get all the information of products stored across 20 pages.

# %%
product_info = []

search_input = 'iphone 13'
url = get_url(search_input)

# To get product data in each page of 20 pages long search result
for page_num in range(1, 21):
    url_full = url + '&page=' + str(page_num)
    driver.get(url_full)
    soup = BeautifulSoup(driver.page_source, 'html.parser')
    
    product_data = soup.find_all('div', {'data-component-type': 's-search-result'})
    for product in product_data:
        info = extract_data(product)
        if info:
            product_info.append(info)

for product in product_info:
    for info in product:
        print(info)
    print()
# Out:
# Apple iPhone 13 Mini (128GB) - Blue
# ₹69,900
# 4.4
# 280
# https://www.amazon.in/gp/slredirect/picassoRedirect.html/ref=pa_sp_atf_aps_sr_pg1_1?ie=UTF8&adId=A033021222S2YH4TY3CLK&url=%2FApple-iPhone-13-Mini-128GB%2Fdp%2FB09G99NBNQ%2Fref%3Dsr_1_1_sspa%3Fkeywords%3Diphone%2B13%26qid%3D1640946212%26sr%3D8-1-spons%26psc%3D1&qualifier=1640946212&id=2074233375148366&widgetName=sp_atf
#
# New Apple iPhone 12 Mini (256GB) - (Product) RED
# ₹64,999
# 4.
# 6,218
# https://www.amazon.in/gp/slredirect/picassoRedirect.html/ref=pa_sp_atf_aps_sr_pg1_1?ie=UTF8&adId=A03142682ROKNU8C01UJ5&url=%2FNew-Apple-iPhone-Mini-256GB%2Fdp%2FB08L5WKDFF%2Fref%3Dsr_1_2_sspa%3Fkeywords%3Diphone%2B13%26qid%3D1640946212%26sr%3D8-2-spons%26psc%3D1&qualifier=1640946212&id=2074233375148366&widgetName=sp_atf
#
# Apple iPhone 13 (256GB) - (Product) RED
# ₹89,900
# 4.6
# 553
# https://www.amazon.in/Apple-iPhone-13-256GB-Product/dp/B09G9HDN4Q/ref=sr_1_3?keywords=iphone+13&qid=1640946212&sr=8-3
#
# Apple iPhone 13 Mini (128GB) - (Product) RED
# ₹69,900
# 4.4
# 280
# https://www.amazon.in/Apple-iPhone-13-Mini-128GB/dp/B09G99WQVX/ref=sr_1_4?keywords=iphone+13&qid=1640946212&sr=8-4
#
# Mobirush iPhone 13 Pro Max Kickstand Hybrid Desk Stand Back Case Cover for iPhone 13 Pro Max - Black
# ₹299
#
#
# https://www.amazon.in/Mobirush-iPhone-13-Pro-Max/dp/B09M8RTWD6/ref=sr_1_5?keywords=iphone+13&qid=1640946212&sr=8-5
#
# Mobirush (Camera Protection) Matte Case Cover for iPhone 13 Pro - Red
# ₹299
#
#
# https://www.amazon.in/Mobirush-Protection-iPhone-13-Pro/dp/B09KM8LXP3/ref=sr_1_7?keywords=iphone+13&qid=1640946212&sr=8-7
#
# Jacure Design for iPhone 13 Mini Tempered Glass Back Side Rear Protector Proper Fit Bubble Free Case Friendly Easy Installation - Black
# ₹499
#
#
# https://www.amazon.in/Jacure-iPhone-13-Mini-Installation/dp/B09P58PHCP/ref=sr_1_8?keywords=iphone+13&qid=1640946212&sr=8-8
#
# New Apple iPhone 12 Pro Max (256GB) - Gold with Apple 20W USB-C Power Adapter
# ₹1,31,749
# 4.7
# 1,466
# https://www.amazon.in/New-Apple-iPhone-Pro-256GB/dp/B08Z72BSJJ/ref=sr_1_9?keywords=iphone+13&qid=1640946212&sr=8-9
#
# Cascov (Camera Protection) Matte Case Cover for iPhone 13 Pro Max - Black
# ₹299
#
#
# https://www.amazon.in/Cascov-Protection-iPhone-Pro-Max/dp/B09N9HPK91/ref=sr_1_10?keywords=iphone+13&qid=1640946212&sr=8-10
#
# Cascov (Camera Protection) Matte Case Cover for iPhone 13 Pro Max - Dark Green
# ₹299
#
#
# https://www.amazon.in/Cascov-Protection-iPhone-Pro-Max/dp/B09N9KY9GG/ref=sr_1_11?keywords=iphone+13&qid=1640946212&sr=8-11
#
# CellKraft Back Cover for i Phone 13 Pro Max Compatible (6.7 Inch) Rainbow Soft Liquid Silicone TPU Case Shockproof | Camera Protection | (Multi-Coloured) | (Multi Colour3)
# ₹399
# .0
# 3
# https://www.amazon.in/CellKraft-Compatible-Shockproof-Protection-Multi-Coloured/dp/B09LMTFQDT/ref=sr_1_12?keywords=iphone+13&qid=1640946212&sr=8-12
#
# Mobirush (Camera Protection) Matte Case Cover for iPhone 13 Mini - Blue
# ₹299
# .0
# 1
# https://www.amazon.in/Mobirush-Protection-iPhone-13-Mini/dp/B09KM5FQ6H/ref=sr_1_13?keywords=iphone+13&qid=1640946212&sr=8-13
#
# Glaslux (Camera Protection) Matte Case Cover for iPhone 13 Mini - Black
# ₹299
# .0
# 1
# https://www.amazon.in/Glaslux-Protection-iPhone-13-Mini/dp/B09KNMGGPP/ref=sr_1_14?keywords=iphone+13&qid=1640946212&sr=8-14
#
# Cascov (Camera Protection) Matte Case Cover for iPhone 13 Pro - Black
# ₹299
#
#
# https://www.amazon.in/Cascov-Protection-iPhone-13-Pro/dp/B09N9JM14V/ref=sr_1_15?keywords=iphone+13&qid=1640946212&sr=8-15
#
# Glaslux iPhone 13 Kickstand Hybrid Desk Stand Back Case Cover for iPhone 13 - Black
# ₹299
#
#
# https://www.amazon.in/Glaslux-iPhone-13-Kickstand-Hybrid/dp/B09M8WH4GC/ref=sr_1_16?keywords=iphone+13&qid=1640946212&sr=8-16
#
# Nillkin Case for Apple iPhone 13 Pro (6.1" Inch) CamShield Silky Soft Liquid Silicon + PC Finish Camera Slider Inner Microfiber Black
# ₹1,314
#
#
# https://www.amazon.in/Nillkin-iPhone-CamShield-Silicon-Microfiber/dp/B09HXZF2DT/ref=sr_1_17?keywords=iphone+13&qid=1640946212&sr=8-17
#
# OJOS Compatible for iPhone 13 Pro/iPhone 13 Pro Max Camera Lens Protector Tempered Glass Screen Protector Case Friendly for iPhone 13Pro / 13 ProMax 2021 (Clear)
# ₹399
#
#
# https://www.amazon.in/OJOS-Compatible-Protector-Tempered-Friendly/dp/B09N3JDQS7/ref=sr_1_18?keywords=iphone+13&qid=1640946212&sr=8-18
#
# Samsung Galaxy M32 5G (Sky Blue, 6GB RAM, 128GB Storage)
# ₹20,999
# 4.2
# 16,515
# https://www.amazon.in/gp/slredirect/picassoRedirect.html/ref=pa_sp_atf_next_aps_sr_pg2_1?ie=UTF8&adId=A03926402I2QNGSMQ21DS&url=%2FSamsung-Galaxy-Blue-128GB-Storage%2Fdp%2FB09CGJK2HG%2Fref%3Dsr_1_17_sspa%3Fkeywords%3Diphone%2B13%26qid%3D1640946214%26sr%3D8-17-spons%26psc%3D1&qualifier=1640946214&id=3693819355748312&widgetName=sp_atf_next
#
# Samsung Galaxy M21 2021 Edition (Charcoal Black, 4GB RAM, 64GB Storage) | FHD+ sAMOLED | 6 Months Free Screen Replacement for Prime (SM-M215GZKDINS)
# ₹12,999
# 4.2
# 199,329
# https://www.amazon.in/gp/slredirect/picassoRedirect.html/ref=pa_sp_atf_next_aps_sr_pg2_1?ie=UTF8&adId=A05959972VC9EP67FDW4T&url=%2FSamsung-Charcoal-Storage-Replacement-SM-M215GZKDINS%2Fdp%2FB098NFJXXL%2Fref%3Dsr_1_18_sspa%3Fkeywords%3Diphone%2B13%26qid%3D1640946214%26sr%3D8-18-spons%26psc%3D1&qualifier=1640946214&id=3693819355748312&widgetName=sp_atf_next
#
# Mobirush (Camera Protection) Matte Case Cover for iPhone 13 - Black
# ₹299
# 4.0
# 2
# https://www.amazon.in/Mobirush-Camera-Protection-iPhone-13/dp/B09KM61VMQ/ref=sr_1_19?keywords=iphone+13&qid=1640946214&sr=8-19
#
# Nillkin Case for Apple iPhone 13 Pro (6.1" Inch) CamShield Pro Camera Slider Double Layered Protection TPU + PC Black Color
# ₹1,021
# 3.7
# 3
# https://www.amazon.in/Nillkin-iPhone-CamShield-Layered-Protection/dp/B09HXZJJZ8/ref=sr_1_20?keywords=iphone+13&qid=1640946214&sr=8-20
#
# Zivite iPhone 13 Pro Max Kickstand Hybrid Desk Stand Back Case Cover for iPhone 13 Pro Max - Black
# ₹299
#
#
# https://www.amazon.in/iPhone-13-Pro-Max-Kickstand/dp/B09M8R2PFH/ref=sr_1_21?keywords=iphone+13&qid=1640946214&sr=8-21
#
# Cascov (Camera Protection) Matte Case Cover for iPhone 13 Pro Max - Red
# ₹299
#
#
# https://www.amazon.in/Cascov-Protection-iPhone-Pro-Max/dp/B09N9L99CD/ref=sr_1_22?keywords=iphone+13&qid=1640946214&sr=8-22
#
# Nillkin Case for Apple iPhone 13 Pro Max (6.7" Inch) CamShield Pro Camera Slider Double Layered Protection TPU + PC Black Color
# ₹1,299
# .0
# 1
# https://www.amazon.in/Nillkin-iPhone-CamShield-Layered-Protection/dp/B09HXYS5RY/ref=sr_1_23?keywords=iphone+13&qid=1640946214&sr=8-23
#
# Cascov (Camera Protection) Matte Case Cover for iPhone 13 Pro Max - Light Green
# ₹299
#
#
# https://www.amazon.in/Cascov-Protection-iPhone-Pro-Max/dp/B09N9LJ5V3/ref=sr_1_24?keywords=iphone+13&qid=1640946214&sr=8-24
#
# Space X Liquid Silicon Soft Back Cover Case for iPhone 13 (6.1 inch) (Blue)
# ₹599
#
#
# https://www.amazon.in/Space-Liquid-Silicon-Cover-iPhone/dp/B09MZJVKCJ/ref=sr_1_25?keywords=iphone+13&qid=1640946214&sr=8-25
#
# Mobirush iPhone 13 Kickstand Hybrid Desk Stand Back Case Cover for iPhone 13 - Red
# ₹299
#
#
# https://www.amazon.in/Mobirush-iPhone-13-Kickstand-Hybrid/dp/B09M8PPYGZ/ref=sr_1_26?keywords=iphone+13&qid=1640946214&sr=8-26
#
# Nillkin Case for Apple iPhone 13 Pro Max (6.7" Inch) Qin Pro Camshield Camera Slider Genuine Classic Leather Flip Folio + Card Slot Black Color
# ₹1,240
# .0
# 1
# https://www.amazon.in/Nillkin-Camshield-Genuine-Classic-Leather/dp/B09M3ST48Z/ref=sr_1_27?keywords=iphone+13&qid=1640946214&sr=8-27
#
# Glaslux (Camera Protection) Matte Case Cover for iPhone 13 - Red
# ₹299
#
#
# https://www.amazon.in/Glaslux-Camera-Protection-iPhone-13/dp/B09KNPP75C/ref=sr_1_28?keywords=iphone+13&qid=1640946214&sr=8-28
#
# Nillkin Case for Apple iPhone 13 Pro Max (6.7" Inch) Qin Pro Camshield Camera Slider Genuine Classic Leather Flip Folio + Card Slot Brown Color
# ₹1,364
#
#
# https://www.amazon.in/Nillkin-Camshield-Genuine-Classic-Leather/dp/B09M3XTCT4/ref=sr_1_29?keywords=iphone+13&qid=1640946214&sr=8-29
#
# LINLO Tempered Glass Screen Protector Compatible for Apple iPhone 13 Mini with Edge to Edge Coverage and Easy Installation Kit, Pack of 1, Black
# ₹149
#
#
# https://www.amazon.in/LINLO-Apple-iPhone-Mini-Installation/dp/B09K4GCPN3/ref=sr_1_30?keywords=iphone+13&qid=1640946214&sr=8-30
#
# New Apple iPhone 12 Mini (128GB) - Black
# ₹64,900
# 4.
# 6,218
# https://www.amazon.in/New-Apple-iPhone-Mini-128GB/dp/B08L5VG843/ref=sr_1_31?keywords=iphone+13&qid=1640946214&sr=8-31
#
# New Apple iPhone 12 Pro (512GB) - Graphite
# ₹1,04,900
# 4.6
# 1,165
# https://www.amazon.in/New-Apple-iPhone-Pro-512GB/dp/B08L5S9TL1/ref=sr_1_32?keywords=iphone+13&qid=1640946214&sr=8-32
#
# New Apple iPhone 12 (128GB) - Black
# ₹68,900
# 4.6
# 7,060
# https://www.amazon.in/New-Apple-iPhone-12-128GB/dp/B08L5WD9D6/ref=sr_1_33?keywords=iphone+13&qid=1640946214&sr=8-33
#
# Apple iPhone XR (64GB) - (Product) RED
# ₹33,999
# 4.
# 4,056
# https://www.amazon.in/New-Apple-iPhone-XR-64GB/dp/B08L8BK9V6/ref=sr_1_34?keywords=iphone+13&qid=1640946214&sr=8-34
#
# Samsung Galaxy M32 5G (Sky Blue, 8GB RAM, 128GB Storage)
# ₹22,999
# 4.2
# 16,515
# https://www.amazon.in/gp/slredirect/picassoRedirect.html/ref=pa_sp_atf_next_aps_sr_pg3_1?ie=UTF8&adId=A03924841FDQXBJJPZXFQ&url=%2FSamsung-Galaxy-Blue-128GB-Storage%2Fdp%2FB09CGJFY5N%2Fref%3Dsr_1_33_sspa%3Fkeywords%3Diphone%2B13%26qid%3D1640946215%26sr%3D8-33-spons%26psc%3D1&qualifier=1640946215&id=7161387042678738&widgetName=sp_atf_next
#
# Samsung Galaxy M12 (White,6GB RAM, 128GB Storage) 6 Months Free Screen Replacement for Prime
# ₹13,499
# 4.1
# 98,693
# https://www.amazon.in/gp/slredirect/picassoRedirect.html/ref=pa_sp_atf_next_aps_sr_pg3_1?ie=UTF8&adId=A04562271DLGB1BOXQN9P&url=%2FSamsung-Galaxy-M12-Storage-Replacement%2Fdp%2FB08XGMNKYW%2Fref%3Dsr_1_34_sspa%3Fkeywords%3Diphone%2B13%26qid%3D1640946215%26sr%3D8-34-spons%26psc%3D1&qualifier=1640946215&id=7161387042678738&widgetName=sp_atf_next
#
# Cascov iPhone 13 Pro Max Kickstand Hybrid Desk Stand Back Case Cover for iPhone 13 Pro Max - Black
# ₹299
#
#
# https://www.amazon.in/Cascov-iPhone-13-Pro-Max/dp/B09MNFK6VY/ref=sr_1_35?keywords=iphone+13&qid=1640946215&sr=8-35
#
# Glaslux (Camera Protection) Matte Case Cover for iPhone 13 - Blue
# ₹299
#
#
# https://www.amazon.in/Glaslux-Camera-Protection-iPhone-13/dp/B09KNMJ552/ref=sr_1_36?keywords=iphone+13&qid=1640946215&sr=8-36
#
# Nillkin Case for Apple iPhone 13 (6.1" Inch) CamShield Pro Camera Slider Double Layered Protection TPU + PC Black Color
# ₹1,258
#
#
# https://www.amazon.in/Nillkin-iPhone-CamShield-Layered-Protection/dp/B09HXYHCHN/ref=sr_1_37?keywords=iphone+13&qid=1640946215&sr=8-37
#
# Glaslux (Camera Protection) Matte Case Cover for iPhone 13 Mini - Light Green
# ₹299
#
#
# https://www.amazon.in/Glaslux-Protection-iPhone-13-Mini/dp/B09KNMDXK4/ref=sr_1_38?keywords=iphone+13&qid=1640946215&sr=8-38
#
# Mobirush iPhone 13 Kickstand Hybrid Desk Stand Back Case Cover for iPhone 13 - Black
# ₹299
#
#
# https://www.amazon.in/Mobirush-iPhone-13-Kickstand-Hybrid/dp/B09M8QPV5N/ref=sr_1_39?keywords=iphone+13&qid=1640946215&sr=8-39
#
# Glaslux (Camera Protection) Matte Case Cover for iPhone 13 Pro - Blue
# ₹299
#
#
# https://www.amazon.in/Glaslux-Protection-iPhone-13-Pro/dp/B09KNMPCST/ref=sr_1_40?keywords=iphone+13&qid=1640946215&sr=8-40
#
# Glaslux (Camera Protection) Matte Case Cover for iPhone 13 Pro - Black
# ₹299
# 4.
# 2
# https://www.amazon.in/Glaslux-Protection-iPhone-13-Pro/dp/B09KNP6L53/ref=sr_1_41?keywords=iphone+13&qid=1640946215&sr=8-41
#
# Glaslux Dazzle Kickstand Hybrid Desk Stand Back Case Cover for iPhone 13 - Red
# ₹299
# .0
# 1
# https://www.amazon.in/Glaslux-Dazzle-Kickstand-iPhone-13/dp/B09M8Y1G2F/ref=sr_1_42?keywords=iphone+13&qid=1640946215&sr=8-42
#
# CellphoneMall Skin-Feel Texture Zipper Wallet Bag Horizontal Flip Leather Case with Holder & Card Slots & Wallet & Lanyard for iPhone 13 Pro
# ₹2,401.85
#
#
# https://www.amazon.in/CellphoneMall-Skin-Feel-Texture-Horizontal-Leather/dp/B09N37SSNZ/ref=sr_1_43?keywords=iphone+13&qid=1640946215&sr=8-43
#
# OxMore Back Cover for i Phone 13 Pro Max Compatible (6.7 Inch) Rainbow Soft Liquid Silicone TPU Case Shockproof | Camera Protection | (Multi-Coloured) |
# ₹299
#
#
# https://www.amazon.in/OxMore-Phone-Pro-Max-Compatible/dp/B09MFGGSM8/ref=sr_1_44?keywords=iphone+13&qid=1640946215&sr=8-44
#
# CellphoneMall All-Inclusive Liquid Silicone Phone Protective Case with Ring Holder & Lanyard for iPhone 13 Pro Max
# ₹2,034.23
#
#
# https://www.amazon.in/CellphoneMall-All-Inclusive-Silicone-Protective-Lanyard/dp/B09NXSNM8F/ref=sr_1_45?keywords=iphone+13&qid=1640946215&sr=8-45
#
# Mobirush iPhone 13 Kickstand Hybrid Desk Stand Back Case Cover for iPhone 13 - Blue
# ₹299
#
#
# https://www.amazon.in/Mobirush-iPhone-13-Kickstand-Hybrid/dp/B09M8RB9NH/ref=sr_1_46?keywords=iphone+13&qid=1640946215&sr=8-46
#
# Jacure Design for iPhone 13 Pro Max Tempered Glass Back Side Rear Protector Proper Fit Bubble Free Case Friendly Easy Installation - Pink
# ₹499
#
#
# https://www.amazon.in/Jacure-iPhone-13-Max-Installation/dp/B09P57XGJC/ref=sr_1_47?keywords=iphone+13&qid=1640946215&sr=8-47
#
# Cascov (Camera Protection) Matte Case Cover for iPhone 13 Pro - Dark Green
# ₹299
#
#
# https://www.amazon.in/Cascov-Protection-iPhone-13-Pro/dp/B09N9GY4Q1/ref=sr_1_48?keywords=iphone+13&qid=1640946215&sr=8-48
#
# Cascov (Camera Protection) Matte Case Cover for iPhone 13 - Light Green
# ₹299
#
#
# https://www.amazon.in/Cascov-Camera-Protection-iPhone-13/dp/B09N9KKQD2/ref=sr_1_49?keywords=iphone+13&qid=1640946215&sr=8-49
#
# Samsung Galaxy M12 (Blue,4GB RAM, 64GB Storage) 6000 mAh with 8nm Processor | True 48 MP Quad Camera | 90Hz Refresh Rate
# ₹11,499
# 4.1
# 98,693
# https://www.amazon.in/Samsung-Galaxy-M12-Storage-Processor/dp/B08XGDN3TZ/ref=sr_1_50?keywords=iphone+13&qid=1640946215&sr=8-50
#
# Samsung Galaxy M32 5G (Slate Black, 6GB RAM, 128GB Storage)
# ₹20,999
# 4.2
# 16,515
# https://www.amazon.in/gp/slredirect/picassoRedirect.html/ref=pa_sp_atf_next_aps_sr_pg4_1?ie=UTF8&adId=A03923282PBEL7H7P7G8Z&url=%2FSamsung-Galaxy-Slate-Black-Storage%2Fdp%2FB09CGLRLYM%2Fref%3Dsr_1_49_sspa%3Fkeywords%3Diphone%2B13%26qid%3D1640946217%26sr%3D8-49-spons%26psc%3D1&qualifier=1640946217&id=7125347136600266&widgetName=sp_atf_next
#
# Samsung Galaxy M12 (Blue,6GB RAM, 128GB Storage) 6 Months Free Screen Replacement for Prime
# ₹13,499
# 4.1
# 98,693
# https://www.amazon.in/gp/slredirect/picassoRedirect.html/ref=pa_sp_atf_next_aps_sr_pg4_1?ie=UTF8&adId=A0456571375XL9IXX3EJ7&url=%2FSamsung-Galaxy-M12-Storage-Replacement%2Fdp%2FB08XJG8MQM%2Fref%3Dsr_1_50_sspa%3Fkeywords%3Diphone%2B13%26qid%3D1640946217%26sr%3D8-50-spons%26psc%3D1&qualifier=1640946217&id=7125347136600266&widgetName=sp_atf_next
#
# Glaslux (Camera Protection) Matte Case Cover for iPhone 13 Mini - Red
# ₹299
#
#
# https://www.amazon.in/Glaslux-Protection-iPhone-13-Mini/dp/B09KNN668G/ref=sr_1_51?keywords=iphone+13&qid=1640946217&sr=8-51
#
# Mobirush (Camera Protection) Matte Case Cover for iPhone 13 - Blue
# ₹299
#
#
# https://www.amazon.in/Mobirush-Camera-Protection-iPhone-13/dp/B09KM6HFHY/ref=sr_1_52?keywords=iphone+13&qid=1640946217&sr=8-52
#
# Zivite iPhone 13 Pro Max Kickstand Hybrid Desk Stand Back Case Cover for iPhone 13 Pro Max - Blue
# ₹299
#
#
# https://www.amazon.in/iPhone-13-Pro-Max-Kickstand/dp/B09M8PPZ1T/ref=sr_1_53?keywords=iphone+13&qid=1640946217&sr=8-53
#
# OnePlus Nord CE 5G (Charcoal Ink, 8GB RAM, 128GB Storage)
# ₹24,999
# 4.1
# 68,787
# https://www.amazon.in/OnePlus-Nord-Charcoal-128GB-Storage/dp/B09576CYNP/ref=sr_1_54?keywords=iphone+13&qid=1640946217&sr=8-54
#
# Mobirush (Camera Protection) Matte Case Cover for iPhone 13 - Red
# ₹299
# .0
# 1
# https://www.amazon.in/Mobirush-Camera-Protection-iPhone-13/dp/B09KM43Y12/ref=sr_1_55?keywords=iphone+13&qid=1640946217&sr=8-55
#
# Zivite iPhone 13 Pro Max Kickstand Hybrid Desk Stand Back Case Cover for iPhone 13 Pro Max - Red
# ₹299
#
#
# https://www.amazon.in/iPhone-13-Pro-Max-Kickstand/dp/B09M8R38J9/ref=sr_1_56?keywords=iphone+13&qid=1640946217&sr=8-56
#
# Glaslux iPhone 13 Pro Max Kickstand Hybrid Desk Stand Back Case Cover for iPhone 13 Pro Max - Blue
# ₹299
#
#
# https://www.amazon.in/Glaslux-iPhone-13-Pro-Max/dp/B09M8Z4YSD/ref=sr_1_58?keywords=iphone+13&qid=1640946217&sr=8-58
#
# Glaslux iPhone 13 Pro Max Kickstand Hybrid Desk Stand Back Case Cover for iPhone 13 Pro Max - Black
# ₹299
#
#
# https://www.amazon.in/Glaslux-iPhone-13-Pro-Max/dp/B09M8YHWZF/ref=sr_1_59?keywords=iphone+13&qid=1640946217&sr=8-59
#
# Glaslux (Camera Protection) Matte Case Cover for iPhone 13 Mini - Blue
# ₹299
#
#
# https://www.amazon.in/Glaslux-Protection-iPhone-13-Mini/dp/B09KNMWHNT/ref=sr_1_60?keywords=iphone+13&qid=1640946217&sr=8-60
#
# Glaslux (Camera Protection) Matte Case Cover for iPhone 13 Pro - Dark Green
# ₹299
#
#
# https://www.amazon.in/Glaslux-Protection-iPhone-13-Pro/dp/B09KNM146P/ref=sr_1_61?keywords=iphone+13&qid=1640946217&sr=8-61
#
# OnePlus Nord 2 5G (Blue Haze, 8GB RAM, 128GB Storage)
# ₹29,999
# 4.3
# 55,814
# https://www.amazon.in/OnePlus-Nord-Blue-128GB-Storage/dp/B097RD2JX8/ref=sr_1_62?keywords=iphone+13&qid=1640946217&sr=8-62
#
# Samsung Galaxy M32 5G (Sky Blue, 8GB RAM, 128GB Storage)
# ₹22,999
# 4.2
# 16,515
# https://www.amazon.in/Samsung-Galaxy-Blue-128GB-Storage/dp/B09CGJFY5N/ref=sr_1_63?keywords=iphone+13&qid=1640946217&sr=8-63
#
# Glaslux Dazzle Kickstand Hybrid Desk Stand Back Case Cover for iPhone 13 Pro Max - Red
# ₹299
#
#
# https://www.amazon.in/Glaslux-iPhone-13-Pro-Max/dp/B09M8X8PPF/ref=sr_1_64?keywords=iphone+13&qid=1640946217&sr=8-64
#
# Samsung Galaxy M21 2021 Edition (Arctic Blue, 4GB RAM, 64GB Storage) | FHD+ sAMOLED | 6 Months Free Screen Replacement for Prime (SM-M215GLBDINS)
# ₹12,999
# 4.2
# 199,329
# https://www.amazon.in/Samsung-Storage-sAMOLED-Replacement-SM-M215GLBDINS/dp/B098NGDNMT/ref=sr_1_65?keywords=iphone+13&qid=1640946217&sr=8-65
#
# Glaslux Dazzle Kickstand Hybrid Desk Stand Back Case Cover for iPhone 13 Pro Max - Blue
# ₹299
#
#
# https://www.amazon.in/Glaslux-iPhone-13-Pro-Max/dp/B09M8XLR1M/ref=sr_1_66?keywords=iphone+13&qid=1640946217&sr=8-66
#
# Samsung Galaxy M32 5G (Slate Black, 8GB RAM, 128GB Storage)
# ₹22,999
# 4.2
# 16,515
# https://www.amazon.in/gp/slredirect/picassoRedirect.html/ref=pa_sp_atf_next_aps_sr_pg5_1?ie=UTF8&adId=A03924282DRXT4E2BKIVG&url=%2FSamsung-Galaxy-Slate-Black-Storage%2Fdp%2FB09CGM3H3Q%2Fref%3Dsr_1_65_sspa%3Fkeywords%3Diphone%2B13%26qid%3D1640946219%26sr%3D8-65-spons%26psc%3D1&qualifier=1640946219&id=2092069138814929&widgetName=sp_atf_next
#
# Samsung Galaxy M12 (Black,6GB RAM, 128GB Storage) 6 Months Free Screen Replacement for Prime
# ₹13,499
# 4.1
# 98,692
# https://www.amazon.in/gp/slredirect/picassoRedirect.html/ref=pa_sp_atf_next_aps_sr_pg5_1?ie=UTF8&adId=A0456627DVRW3UVP6A6N&url=%2FSamsung-Galaxy-M12-Storage-Replacement%2Fdp%2FB08XJBPCTR%2Fref%3Dsr_1_66_sspa%3Fkeywords%3Diphone%2B13%26qid%3D1640946219%26sr%3D8-66-spons%26psc%3D1&qualifier=1640946219&id=2092069138814929&widgetName=sp_atf_next
#
# Tecno Spark 8T (Atlantic Blue,4GB RAM, 64GB Storage)| 50MP AI Camera | 6.6" FHD+Display | 5000mAh
# ₹9,499
# 4.2
# 70
# https://www.amazon.in/Tecno-Spark-8T-Atlantic-64GB/dp/B09MKPX6RQ/ref=sr_1_67?keywords=iphone+13&qid=1640946219&sr=8-67
#
# Cascov (Camera Protection) Matte Case Cover for iPhone 13 Mini - Black
# ₹299
#
#
# https://www.amazon.in/Cascov-Protection-iPhone-13-Mini/dp/B09N9KPRR4/ref=sr_1_68?keywords=iphone+13&qid=1640946219&sr=8-68
#
# Kaizen Enterprises Vaku World's Smallest Dual-Sim Nano Phone with Voice Changer, Alarm, Bluetooth and More
# ₹2,900
# 3.3
# 4
# https://www.amazon.in/Kaizen-Enterprises-Smallest-Dual-Sim-Bluetooth/dp/B09FZP5HJZ/ref=sr_1_69?keywords=iphone+13&qid=1640946219&sr=8-69
#
# CellphoneMall Camera Cover & Holder Design TPU + PC Phone Case for iPhone 13 Pro Max
# ₹1,120.58
#
#
# https://www.amazon.in/CellphoneMall-Camera-Holder-Design-iPhone/dp/B09MKGZRHZ/ref=sr_1_70?keywords=iphone+13&qid=1640946219&sr=8-70
#
# Samsung Galaxy S20 FE 5G (Cloud Navy, 8GB RAM, 128GB Storage) with No Cost EMI & Additional Exchange Offers
# ₹49,990
# 4.4
# 6,353
# https://www.amazon.in/Samsung-Galaxy-Cloud-128GB-Storage/dp/B08VB57558/ref=sr_1_71?keywords=iphone+13&qid=1640946219&sr=8-71
#
# New Apple iPhone 12 (128GB) - Black with AirPods with Charging Case
# ₹80,899
# 4.9
# 27
# https://www.amazon.in/New-Apple-iPhone-12-128GB/dp/B08ZWMRX4V/ref=sr_1_72?keywords=iphone+13&qid=1640946219&sr=8-72
#
# CellphoneMall Simple Wax Texture Horizontal Flip Leather Case with Card Slots & Wallet for iPhone 13 Pro
# ₹2,251.09
#
#
# https://www.amazon.in/CellphoneMall-Simple-Texture-Horizontal-Leather/dp/B09NKPWJGG/ref=sr_1_73?keywords=iphone+13&qid=1640946219&sr=8-73
#
# Samsung Galaxy M32 (Light Blue, 6GB RAM, 128GB Storage) 6 Months Free Screen Replacement for Prime
# ₹16,999
# 4.2
# 24,893
# https://www.amazon.in/Samsung-Galaxy-Storage-Months-Replacement/dp/B096VDR283/ref=sr_1_74?keywords=iphone+13&qid=1640946219&sr=8-74
#
# iQOO Z3 5G (Ace Black, 6GB RAM, 128GB Storage) | India's First SD 768G 5G Processor | 55W FlashCharge | Upto 9 Months No Cost EMI | 6 Months Free Screen Replacement
# ₹19,990
# 4.3
# 38,614
# https://www.amazon.in/iQOO-Storage-Processor-FlashCharge-Replacement/dp/B07WHR5RKH/ref=sr_1_75?keywords=iphone+13&qid=1640946219&sr=8-75
#
# Glaslux (Camera Protection) Matte Case Cover for iPhone 13 Pro - Red
# ₹299
#
#
# https://www.amazon.in/Glaslux-Protection-iPhone-13-Pro/dp/B09KNMBD7K/ref=sr_1_76?keywords=iphone+13&qid=1640946219&sr=8-76
#
# Nillkin Case for Apple iPhone 13 Pro Max (6.7" Inch) CamShield Pro Camera Slider Double Layered Protection TPU + PC Blue Color
# ₹2,060
#
#
# https://www.amazon.in/Nillkin-iPhone-CamShield-Layered-Protection/dp/B09HY1MF1F/ref=sr_1_77?keywords=iphone+13&qid=1640946219&sr=8-77
#
# Nillkin Case for Apple iPhone 13 Pro (6.1" Inch) CamShield Silky Soft Liquid Silicon + PC Finish Camera Slider Inner Microfiber Green
# ₹3,999
#
#
# https://www.amazon.in/Nillkin-iPhone-CamShield-Silicon-Microfiber/dp/B09HXYCR1G/ref=sr_1_78?keywords=iphone+13&qid=1640946219&sr=8-78
#
# Nillkin Case for Apple iPhone 13 Mini (5.4" Inch) CamShield Pro Camera Slider Double Layered Protection TPU + PC Blue Color
# ₹1,789
#
#
# https://www.amazon.in/Nillkin-iPhone-CamShield-Layered-Protection/dp/B09HXYF7BV/ref=sr_1_79?keywords=iphone+13&qid=1640946219&sr=8-79
#
# Zivite iPhone 13 Pro Defender Case | Rotating Ring Holder & Kickstand in-Built | Military Grade Armor | Bumper Back Cover for iPhone 13 Pro (Transparent)
# ₹299
#
#
# https://www.amazon.in/iPhone-13-Pro-Kickstand-Transparent/dp/B09LHVB3CT/ref=sr_1_80?keywords=iphone+13&qid=1640946219&sr=8-80
#
# Nillkin Case for Apple iPhone 13 Pro Max (6.7" Inch) Qin Pro Camshield Camera Slider Genuine Classic Leather Flip Folio + Card Slot Red Color
# ₹1,999
#
#
# https://www.amazon.in/Nillkin-Camshield-Genuine-Classic-Leather/dp/B09M3VV37J/ref=sr_1_81?keywords=iphone+13&qid=1640946219&sr=8-81
#
# Redmi 9 (Sporty Orange, 4GB RAM, 64GB Storage) | 2.3GHz Mediatek Helio G35 Octa core Processor
# ₹9,499
# 4.2
# 129,323
# https://www.amazon.in/Redmi-Sporty-Orange-64GB-Storage/dp/B08696W3B3/ref=sr_1_82?keywords=iphone+13&qid=1640946219&sr=8-82
#
# Samsung Galaxy M32 (Black, 6GB RAM, 128GB Storage) 6 Months Free Screen Replacement for Prime
# ₹16,999
# 4.2
# 24,893
# https://www.amazon.in/gp/slredirect/picassoRedirect.html/ref=pa_sp_atf_next_aps_sr_pg6_1?ie=UTF8&adId=A09807472OL0OFTIQLN0D&url=%2FSamsung-Galaxy-Storage-Months-Replacement%2Fdp%2FB096VD6RQG%2Fref%3Dsr_1_81_sspa%3Fkeywords%3Diphone%2B13%26qid%3D1640946221%26sr%3D8-81-spons%26psc%3D1&qualifier=1640946221&id=6786632357490860&widgetName=sp_atf_next
#
# OnePlus 9 Pro 5G (Morning Mist, 12GB RAM, 256GB Storage)
# ₹69,999
# 4.3
# 7,507
# https://www.amazon.in/Test-Exclusive_2020_1167-Multi-3GB-Storage/dp/B089MV3MVY/ref=sr_1_82?keywords=iphone+13&qid=1640946221&sr=8-82
#
# Mobirush iPhone 13 Pro Max Kickstand Hybrid Desk Stand Back Case Cover for iPhone 13 Pro Max - Blue
# ₹299
#
#
# https://www.amazon.in/Mobirush-iPhone-13-Pro-Max/dp/B09M8RJWYM/ref=sr_1_83?keywords=iphone+13&qid=1640946221&sr=8-83
#
# Cascov (Camera Protection) Matte Case Cover for iPhone 13 Mini - Blue
# ₹299
#
#
# https://www.amazon.in/Cascov-Protection-iPhone-13-Mini/dp/B09N9K1QLR/ref=sr_1_84?keywords=iphone+13&qid=1640946221&sr=8-84
#
# OnePlus 9 5G (Winter Mist, 12GB RAM, 256GB Storage)
# ₹54,999
# 4.2
# 8,180
# https://www.amazon.in/Test-Exclusive_2020_1173-Multi-3GB-Storage/dp/B089MSGHJQ/ref=sr_1_86?keywords=iphone+13&qid=1640946221&sr=8-86
#
# Nillkin Case for Apple iPhone 13 Pro (6.1" Inch) CamShield Silky Soft Liquid Silicon + PC Finish Camera Slider Inner Microfiber Purple
# ₹3,999
#
#
# https://www.amazon.in/Nillkin-iPhone-CamShield-Silicon-Microfiber/dp/B09HXYYNM5/ref=sr_1_87?keywords=iphone+13&qid=1640946221&sr=8-87
#
# Mobirush (Camera Protection) Matte Case Cover for iPhone 13 Mini - Dark Green
# ₹299
#
#
# https://www.amazon.in/Mobirush-Protection-iPhone-13-Mini/dp/B09KM6SQHK/ref=sr_1_88?keywords=iphone+13&qid=1640946221&sr=8-88
#
# Cascov iPhone 13 Pro Max Kickstand Hybrid Desk Stand Back Case Cover for iPhone 13 Pro Max - Blue
# ₹299
#
#
# https://www.amazon.in/Cascov-iPhone-13-Pro-Max/dp/B09MNHV8WL/ref=sr_1_89?keywords=iphone+13&qid=1640946221&sr=8-89
#
# Kechaoda K116, Dual Sim (Fusion Gold)
# ₹1,147
# 3.6
# 535
# https://www.amazon.in/Kechaoda-K116-Dual-Fusion-Gold/dp/B08YWJ9QCJ/ref=sr_1_90?keywords=iphone+13&qid=1640946221&sr=8-90
#
# Cascov (Camera Protection) Matte Case Cover for iPhone 13 Pro - Light Green
# ₹299
#
#
# https://www.amazon.in/Cascov-Protection-iPhone-13-Pro/dp/B09N9JVL6H/ref=sr_1_91?keywords=iphone+13&qid=1640946221&sr=8-91
#
# Samsung Galaxy M52 5G (Blazing Black, 6GB RAM, 128GB Storage) Latest Snapdragon 778G 5G | sAMOLED 120Hz Display
# ₹29,999
# 4.2
# 7,368
# https://www.amazon.in/Samsung-Blazing-Storage-Snapdragon-sAMOLED/dp/B09CV463ZY/ref=sr_1_92?keywords=iphone+13&qid=1640946221&sr=8-92
#
# Cascov iPhone 13 Pro Max Kickstand Hybrid Desk Stand Back Case Cover for iPhone 13 Pro Max - Red
# ₹299
#
#
# https://www.amazon.in/Cascov-iPhone-13-Pro-Max/dp/B09MNHZRSY/ref=sr_1_93?keywords=iphone+13&qid=1640946221&sr=8-93
#
# CellphoneMall Texture Horizontal Flip Leather Case with Holder & Card Slots & Wallet for iPhone 13 Pro Max
# ₹2,600.09
#
#
# https://www.amazon.in/CellphoneMall-Texture-Horizontal-Leather-Holder/dp/B09NLLY2VT/ref=sr_1_94?keywords=iphone+13&qid=1640946221&sr=8-94
#
# Mobirush (Camera Protection) Matte Case Cover for iPhone 13 - Dark Green
# ₹299
#
#
# https://www.amazon.in/Mobirush-Camera-Protection-iPhone-13/dp/B09KM5FHFJ/ref=sr_1_95?keywords=iphone+13&qid=1640946221&sr=8-95
#
# Nillkin Case for Apple iPhone 13 (6.1" Inch) CamShield Silky Soft Liquid Silicon + PC Finish Camera Slider Inner Microfiber Blue
# ₹3,999
#
#
# https://www.amazon.in/Nillkin-iPhone-CamShield-Silicon-Microfiber/dp/B09HXZ23F2/ref=sr_1_96?keywords=iphone+13&qid=1640946221&sr=8-96
#
# OnePlus 9R 5G (Carbon Black, 8GB RAM, 128GB Storage)
# ₹39,999
# 4.4
# 32,535
# https://www.amazon.in/Test-Exclusive_2020_1178-Multi-3GB-Storage/dp/B089MTJVLD/ref=sr_1_97?keywords=iphone+13&qid=1640946221&sr=8-97
#
# Samsung Galaxy M32 (Light Blue, 6GB RAM, 128GB Storage) 6 Months Free Screen Replacement for Prime
# ₹16,999
# 4.2
# 24,893
# https://www.amazon.in/gp/slredirect/picassoRedirect.html/ref=pa_sp_atf_next_aps_sr_pg7_1?ie=UTF8&adId=A09807231DT00CUIY4XJY&url=%2FSamsung-Galaxy-Storage-Months-Replacement%2Fdp%2FB096VDR283%2Fref%3Dsr_1_97_sspa%3Fkeywords%3Diphone%2B13%26qid%3D1640946224%26sr%3D8-97-spons%26psc%3D1&qualifier=1640946224&id=6971751236573263&widgetName=sp_atf_next
#
# Jacure Compatible for iPhone 13/13 Pro Max Matte Finish Ceramic Screen Protector Flexible Film TPU Screen Protector for iPhone 13 Pro Max 6.7 Inch [Case Friendly] [Full Coverage] - Black
# ₹199
#
#
# https://www.amazon.in/Jacure-Compatible-iPhone-Pro-Max/dp/B09MD83WZZ/ref=sr_1_98?keywords=iphone+13&qid=1640946224&sr=8-98
#
# Cascov (Camera Protection) Matte Case Cover for iPhone 13 Pro Max - Blue
# ₹299
#
#
# https://www.amazon.in/Cascov-Protection-iPhone-Pro-Max/dp/B09N9KNBVL/ref=sr_1_99?keywords=iphone+13&qid=1640946224&sr=8-99
#
# Magnetic Wireless Power Bank, 20W PD+QC 10000mAh Portable Fast Magnetic Charger, Compatible with iPhone 13/13 Pro/ 12 Mini Pro Max,Wireless Charging Android Phones Earphones (Blue)
# ₹3,990
#
#
# https://www.amazon.in/Magnetic-Wireless-10000mAh-Compatible-Earphones/dp/B09KXR94YS/ref=sr_1_100?keywords=iphone+13&qid=1640946224&sr=8-100
#
# Mobirush (Camera Protection) Matte Case Cover for iPhone 13 Pro - Blue
# ₹299
#
#
# https://www.amazon.in/Mobirush-Protection-iPhone-13-Pro/dp/B09KM56LD6/ref=sr_1_101?keywords=iphone+13&qid=1640946224&sr=8-101
#
# Redmi Note 10S (Cosmic Purple, 6GB RAM, 64 GB Storage) - Super Amoled Display | 64 MP Quad Camera | Alexa Built in
# ₹14,999
# 4.2
# 39,918
# https://www.amazon.in/Redmi-Note-Cosmic-Purple-Storage/dp/B09C6BPT7L/ref=sr_1_102?keywords=iphone+13&qid=1640946224&sr=8-102
#
# Nzon Compatible for iPhone 13/13 Pro Privacy Guard Soft Matte Finish Anti Glare Scratch Proof Bubble Free Ceramic Private Anti Spy Screen Protector for i13Pro Front Screen - Black
# ₹699
# 3.0
# 1
# https://www.amazon.in/Compatible-iPhone-13-Pro-Protector/dp/B09LF6RW4R/ref=sr_1_103?keywords=iphone+13&qid=1640946224&sr=8-103
#
# Cascov iPhone 13 Kickstand Hybrid Desk Stand Back Case Cover for iPhone 13 - Black
# ₹299
#
#
# https://www.amazon.in/Cascov-iPhone-13-Kickstand-Hybrid/dp/B09MNG3N52/ref=sr_1_104?keywords=iphone+13&qid=1640946224&sr=8-104
#
# Cascov (Camera Protection) Matte Case Cover for iPhone 13 Pro - Red
# ₹299
#
#
# https://www.amazon.in/Cascov-Protection-iPhone-13-Pro/dp/B09N9HQVYG/ref=sr_1_105?keywords=iphone+13&qid=1640946224&sr=8-105
#
# Nzon Compatible for iPhone 13 Mini Privacy Guard Soft Matte Finish Anti Glare Scratch Proof Bubble Free Ceramic Private Anti Spy Screen Protector for i13 Mini Front Screen - Black
# ₹699
# 4.0
# 1
# https://www.amazon.in/Compatible-iPhone-13-Mini-Protector/dp/B09LF7R42S/ref=sr_1_106?keywords=iphone+13&qid=1640946224&sr=8-106
#
# Glaslux (Camera Protection) Matte Case Cover for iPhone 13 - Light Green
# ₹299
#
#
# https://www.amazon.in/Glaslux-Camera-Protection-iPhone-13/dp/B09KNM5D8C/ref=sr_1_107?keywords=iphone+13&qid=1640946224&sr=8-107
#
# Nzon Design for iPhone 13 Mini Tempered Glass Back Side Rear Protector Proper Fit Bubble Free Case Friendly Easy Installation - Pacific Blue
# ₹499
#
#
# https://www.amazon.in/iPhone-13-Mini-Protector-Installation/dp/B09P3Z722H/ref=sr_1_108?keywords=iphone+13&qid=1640946224&sr=8-108
#
# Glaslux iPhone 13 Kickstand Hybrid Desk Stand Back Case Cover for iPhone 13 - Red
# ₹299
#
#
# https://www.amazon.in/Glaslux-iPhone-13-Kickstand-Hybrid/dp/B09M8WD63B/ref=sr_1_109?keywords=iphone+13&qid=1640946224&sr=8-109
#
# OPPO A74 5G (Fluid Black,6GB RAM,128GB Storage) - 5G Android Smartphone | 5000 mAh Battery | 18W Fast Charge | 90Hz LCD Display
# ₹17,990
# 4.2
# 18,537
# https://www.amazon.in/OPPO-Fluid-Black-128GB-Storage/dp/B08VB2CMR3/ref=sr_1_110?keywords=iphone+13&qid=1640946224&sr=8-110
#
# Samsung Galaxy Z Flip3 5G (Cream, 8GB RAM, 128GB Storage) with No Cost EMI/Additional Exchange Offers + 7000 Instant Discount on HDFC/SBI/ICICI Cards*
# ₹84,999
# 4.2
# 130
# https://www.amazon.in/Samsung-Storage-Additional-Exchange-Discount/dp/B09CQ2TPDQ/ref=sr_1_111?keywords=iphone+13&qid=1640946224&sr=8-111
#
# Pantano Back Screen Protector Side Cover for iPhone 13 Pro Max Anti Scratch Bubble Free Full Side Cover Back Screen Guard Compatible for iPhone 13 Pro Max (Transparent)
# ₹269
# 3.0
# 1
# https://www.amazon.in/Pantano-Protector-Scratch-Compatible-Transparent/dp/B09KNJ7HXJ/ref=sr_1_112?keywords=iphone+13&qid=1640946224&sr=8-112
#
# Nillkin Case for Apple iPhone 13 (6.1" Inch) CamShield Pro Camera Slider Double Layered Protection TPU + PC Blue Color
# ₹1,999
#
#
# https://www.amazon.in/Nillkin-iPhone-CamShield-Layered-Protection/dp/B09HXY44LD/ref=sr_1_113?keywords=iphone+13&qid=1640946224&sr=8-113
#
# Samsung Galaxy M32 (Light Blue, 4GB RAM, 64GB Storage) 6 Months Free Screen Replacement for Prime
# ₹14,999
# 4.2
# 24,893
# https://www.amazon.in/gp/slredirect/picassoRedirect.html/ref=pa_sp_atf_next_aps_sr_pg8_1?ie=UTF8&adId=A0980847BGGOY2GJGCR2&url=%2FSamsung-Galaxy-Storage-Months-Replacement%2Fdp%2FB096VD213D%2Fref%3Dsr_1_113_sspa%3Fkeywords%3Diphone%2B13%26qid%3D1640946225%26sr%3D8-113-spons%26psc%3D1&qualifier=1640946225&id=3541363749006686&widgetName=sp_atf_next
#
# Tecno Spark 7T(Jewel Blue, 4GB RAM, 64GB Storage) 6000 mAh Battery| 48 MP AI Dual Rear Camera
# ₹9,499
# 4.1
# 14,226
# https://www.amazon.in/Tecno-Spark-Storage-Battery-Camera/dp/B096LS7N6Z/ref=sr_1_114?keywords=iphone+13&qid=1640946225&sr=8-114
#
# iQOO Z5 5G (Arctic Dawn, 8GB RAM, 128GB Storage) | Snapdragon 778G 5G Processor | 5000mAh Battery | 44W FlashCharge
# ₹23,990
# 4.3
# 4,278
# https://www.amazon.in/iQOO-Storage-Snapdragon-Processor-FlashCharge/dp/B07WGPJV3H/ref=sr_1_115?keywords=iphone+13&qid=1640946225&sr=8-115
#
# CellphoneMall Electroplating Lambskin Ring Holder Phone Case for iPhone 13 Pro Max
# ₹2,066.74
#
#
# https://www.amazon.in/CellphoneMall-Electroplating-Lambskin-Holder-iPhone/dp/B09NLKGPBX/ref=sr_1_116?keywords=iphone+13&qid=1640946225&sr=8-116
#
# Cascov (Camera Protection) Matte Case Cover for iPhone 13 Mini - Light Green
# ₹299
#
#
# https://www.amazon.in/Cascov-Protection-iPhone-13-Mini/dp/B09N9KSS89/ref=sr_1_117?keywords=iphone+13&qid=1640946225&sr=8-117
#
# Mi 11X 5G Cosmic Black 6GB RAM 128GB ROM | SD 870 | DisplayMate A+ rated E4 AMOLED | Upto 18 Months No Cost EMI
# ₹27,999
# 4.1
# 22,746
# https://www.amazon.in/11X-Cosmic-Black-128GB-Storage/dp/B085J1QWFV/ref=sr_1_118?keywords=iphone+13&qid=1640946225&sr=8-118
#
# Jacure Design for iPhone 13 Mini Tempered Glass Back Side Rear Protector Proper Fit Bubble Free Case Friendly Easy Installation - White
# ₹499
#
#
# https://www.amazon.in/Jacure-iPhone-13-Mini-Installation/dp/B09P57K8X2/ref=sr_1_119?keywords=iphone+13&qid=1640946225&sr=8-119
#
# Pantano Back Screen Protector Anti Scratch Bubble Free Side Cover Back Screen Guard Compatible for iPhone 13 (Transparent)
# ₹269
#
#
# https://www.amazon.in/Pantano-Protector-Scratch-Compatible-Transparent/dp/B09KNFMDL3/ref=sr_1_120?keywords=iphone+13&qid=1640946225&sr=8-120
#
# Nillkin Case for Apple iPhone 13 (6.1" Inch) CamShield Silky Soft Liquid Silicon + PC Finish Camera Slider Inner Microfiber Purple
# ₹3,999
#
#
# https://www.amazon.in/Nillkin-iPhone-CamShield-Silicon-Microfiber/dp/B09HXYPVPV/ref=sr_1_121?keywords=iphone+13&qid=1640946225&sr=8-121
#
# Apple iPhone 11 (256GB) - Purple
# ₹64,900
# 4.6
# 62,108
# https://www.amazon.in/New-Apple-iPhone-11-256GB/dp/B08L8D6TC5/ref=sr_1_122?keywords=iphone+13&qid=1640946225&sr=8-122
#
# Cascov iPhone 13 Pro Rotating Ring Holder & Kickstand in-Built | Military Grade Armor | Bumper Back Cover for iPhone 13 Pro (Transparent)
# ₹299
#
#
# https://www.amazon.in/Cascov-iPhone-13-Pro-Transparent/dp/B09P4ZDQN2/ref=sr_1_123?keywords=iphone+13&qid=1640946225&sr=8-123
#
# Vivo Y20T (Purist Blue, 6GB RAM, 64GB Storage) No Cost EMI/Additional Exchange Offers (Y20T (6GB RAM, 64GB ROM))
# ₹15,489
# 4.4
# 66
# https://www.amazon.in/Vivo-Y20T-6GB-RAM-64GB/dp/B09J2HZQZH/ref=sr_1_124?keywords=iphone+13&qid=1640946225&sr=8-124
#
# Nillkin Case for Apple iPhone 13 (6.1" Inch) CamShield Pro Camera Slider Double Layered Protection TPU + PC Green Color
# ₹999
#
#
# https://www.amazon.in/Nillkin-iPhone-CamShield-Layered-Protection/dp/B09HXYHKC6/ref=sr_1_125?keywords=iphone+13&qid=1640946225&sr=8-125
#
# CellphoneMall Pure Color Horizontal Flip Leather Case with Holder & Card Slots & Wallet & Lanyard for iPhone 13 Pro
# ₹2,075.59
#
#
# https://www.amazon.in/CellphoneMall-Horizontal-Leather-Holder-Lanyard/dp/B09N37XG1W/ref=sr_1_126?keywords=iphone+13&qid=1640946225&sr=8-126
#
# Zivite iPhone 13 (6.1) Defender Case | Rotating Ring Holder & Kickstand in-Built | Military Grade Armor | Bumper Back Cover for iPhone 13 (6.1) (Transparent)
# ₹299
#
#
# https://www.amazon.in/iPhone-13-Defender-Kickstand-Transparent/dp/B09LHV3BSZ/ref=sr_1_127?keywords=iphone+13&qid=1640946225&sr=8-127
#
# Nillkin Case for Apple iPhone 13 Pro Max (6.7" Inch) Qin Pro Camshield Camera Slider Genuine Classic Leather Flip Folio + Card Slot Blue Color
# ₹1,999
#
#
# https://www.amazon.in/Nillkin-Camshield-Genuine-Classic-Leather/dp/B09M3WK1QZ/ref=sr_1_128?keywords=iphone+13&qid=1640946225&sr=8-128
#
# Cascov (Camera Protection) Matte Case Cover for iPhone 13 Mini - Red
# ₹299
#
#
# https://www.amazon.in/Cascov-Protection-iPhone-13-Mini/dp/B09N9JVSJ7/ref=sr_1_129?keywords=iphone+13&qid=1640946225&sr=8-129
#
# Samsung Galaxy M32 (Black, 4GB RAM, 64GB Storage) 6 Months Free Screen Replacement for Prime
# ₹14,999
# 4.2
# 24,893
# https://www.amazon.in/gp/slredirect/picassoRedirect.html/ref=pa_sp_atf_next_aps_sr_pg9_1?ie=UTF8&adId=A09809032P7QCHEJN1VEV&url=%2FSamsung-Galaxy-Storage-Months-Replacement%2Fdp%2FB096VDG9QV%2Fref%3Dsr_1_129_sspa%3Fkeywords%3Diphone%2B13%26qid%3D1640946227%26sr%3D8-129-spons%26psc%3D1&qualifier=1640946227&id=5496128722902580&widgetName=sp_atf_next
#
# Jacure Design for iPhone 13 Pro Max Tempered Glass Back Side Rear Protector Proper Fit Bubble Free Case Friendly Easy Installation - White
# ₹499
#
#
# https://www.amazon.in/Jacure-iPhone-13-Max-Installation/dp/B09P578K52/ref=sr_1_130?keywords=iphone+13&qid=1640946227&sr=8-130
#
# CellphoneMall Four Corners Shocproof Flow Gold Marble IMD Back Cover Case with Metal Rhinestone Ring for iPhone 13 Pro Max
# ₹2,245.53
#
#
# https://www.amazon.in/CellphoneMall-Corners-Shocproof-Marble-Rhinestone/dp/B09NLL5GHR/ref=sr_1_131?keywords=iphone+13&qid=1640946227&sr=8-131
#
# CellphoneMall Electroplating Frame Double Sides Tempered Glass Magnetic Adsorption Phone Case for iPhone 13 Pro Max
# ₹3,009.19
#
#
# https://www.amazon.in/CellphoneMall-Electroplating-Tempered-Magnetic-Adsorption/dp/B09NLL7HM9/ref=sr_1_132?keywords=iphone+13&qid=1640946227&sr=8-132
#
# CellphoneMall Multifunctional Texture Horizontal Flip Leather Case with 9 Card Slot & Holder & Zipper Wallet & Lanyard for iPhone 13 Pro
# ₹2,348.47
#
#
# https://www.amazon.in/CellphoneMall-Multifunctional-Texture-Horizontal-Leather/dp/B09N37GJXB/ref=sr_1_133?keywords=iphone+13&qid=1640946227&sr=8-133
#
# CellphoneMall Peacock Embossed Pattern Horizontal Flip Leather Case with Holder & Card Slots & Wallet & Lanyard for iPhone 13 Pro Max
# ₹1,347.98
#
#
# https://www.amazon.in/CellphoneMall-Peacock-Embossed-Pattern-Horizontal/dp/B09MKF7WS7/ref=sr_1_134?keywords=iphone+13&qid=1640946227&sr=8-134
#
# CellphoneMall Pure Color Horizontal Flip Leather Case with Holder & Card Slots & Wallet & Lanyard for iPhone 13 Pro Max
# ₹2,071.15
#
#
# https://www.amazon.in/CellphoneMall-Horizontal-Leather-Holder-Lanyard/dp/B09PB93CK1/ref=sr_1_135?keywords=iphone+13&qid=1640946227&sr=8-135
#
# Apple iPhone 11 Pro (64GB) - Silver
# ₹89,900
# 4.6
# 1,300
# https://www.amazon.in/Apple-iPhone-11-Pro-64GB/dp/B07XLS56G6/ref=sr_1_136?keywords=iphone+13&qid=1640946227&sr=8-136
#
# CellphoneMall Lace Pattern Double Button Zipper Horizontal Flip Leather Case with Holder & Card Slots & Wallet for iPhone 13 Pro Max
# ₹2,292.50
#
#
# https://www.amazon.in/CellphoneMall-Pattern-Double-Horizontal-Leather/dp/B09NLLDTLK/ref=sr_1_137?keywords=iphone+13&qid=1640946227&sr=8-137
#
# Glaslux iPhone 13 Kickstand Hybrid Desk Stand Back Case Cover for iPhone 13 - Blue
# ₹299
#
#
# https://www.amazon.in/Glaslux-iPhone-13-Kickstand-Hybrid/dp/B09M8WKNW4/ref=sr_1_138?keywords=iphone+13&qid=1640946227&sr=8-138
#
# Glaslux iPhone 13 Pro Max Kickstand Hybrid Desk Stand Back Case Cover for iPhone 13 Pro Max - Red
# ₹299
#
#
# https://www.amazon.in/Glaslux-iPhone-13-Pro-Max/dp/B09M8XK2Z2/ref=sr_1_139?keywords=iphone+13&qid=1640946227&sr=8-139
#
# Jacure™ Compatible for iPhone 13 Back Glass, 3D Tempered Glass case Friendly 9h Hardness Anti Scratch Anti Explosion i13 Rear Tempered Glass - Transparent
# ₹399
#
#
# https://www.amazon.in/JacureTM-Compatible-iPhone-13-Explosion/dp/B09MD7MTJP/ref=sr_1_140?keywords=iphone+13&qid=1640946227&sr=8-140
#
# Mobirush iPhone 13 Pro Max Kickstand Hybrid Desk Stand Back Case Cover for iPhone 13 Pro Max - Red
# ₹299
#
#
# https://www.amazon.in/Mobirush-iPhone-13-Pro-Max/dp/B09M8QMNB4/ref=sr_1_142?keywords=iphone+13&qid=1640946227&sr=8-142
#
# Nokia G20, 48MP Quad Camera, 5050 mAh Battery, 6.5” HD+ Screen, 4 + 64GB Memory
# ₹12,490
# 3.7
# 1,913
# https://www.amazon.in/Nokia-G20-Camera-Battery-Screen/dp/B0986MQRFB/ref=sr_1_143?keywords=iphone+13&qid=1640946227&sr=8-143
#
# CellphoneMall Side Zipper Back Card Horizontal Flip PU Leather Case with Card Slots & Wallet & Photo Frame & Lanyard for iPhone 13 Pro
# ₹2,362.56
#
#
# https://www.amazon.in/CellphoneMall-Zipper-Horizontal-Leather-Lanyard/dp/B09MS3R34D/ref=sr_1_144?keywords=iphone+13&qid=1640946227&sr=8-144
#
# Nzon Compatible for iPhone 13 Mini Screen Protector Flexible TPU Protector Film for (5.7inch) Face id Support Fingerprint Unlocking Anti-Scratch self Healing Full Coverage Touch Sensetive - Clear
# ₹399
#
#
# https://www.amazon.in/Compatible-iPhone-Mini-Fingerprint-Anti-Scratch/dp/B09LRFLB9W/ref=sr_1_145?keywords=iphone+13&qid=1640946227&sr=8-145
#
# Samsung Galaxy Z Fold3 5G (Phantom Black, 12GB RAM, 512GB Storage) with No Cost EMI/Additional Exchange Offers
# ₹1,57,999
# 4.2
# 85
# https://www.amazon.in/Samsung-Phantom-Storage-Additional-Exchange/dp/B09CQ3GSJ1/ref=sr_1_145?keywords=iphone+13&qid=1640946230&sr=8-145
#
# Nillkin Case for Apple iPhone 13 Pro (6.1" Inch) CamShield Pro Camera Slider Double Layered Protection TPU + PC Blue Color
# ₹2,260
#
#
# https://www.amazon.in/Nillkin-iPhone-CamShield-Layered-Protection/dp/B09HXYSJD6/ref=sr_1_146?keywords=iphone+13&qid=1640946230&sr=8-146
#
# Glaslux Dazzle Kickstand Hybrid Desk Stand Back Case Cover for iPhone 13 Pro Max - Black
# ₹299
#
#
# https://www.amazon.in/Glaslux-iPhone-13-Pro-Max/dp/B09M916NFL/ref=sr_1_147?keywords=iphone+13&qid=1640946230&sr=8-147
#
# Cascov iPhone 13 Kickstand Hybrid Desk Stand Back Case Cover for iPhone 13 - Red
# ₹299
#
#
# https://www.amazon.in/Cascov-iPhone-13-Kickstand-Hybrid/dp/B09MNFQVLH/ref=sr_1_148?keywords=iphone+13&qid=1640946230&sr=8-148
#
# Mobirush (Camera Protection) Matte Case Cover for iPhone 13 Pro - Light Green
# ₹299
#
#
# https://www.amazon.in/Mobirush-Protection-iPhone-13-Pro/dp/B09KM8D3LZ/ref=sr_1_149?keywords=iphone+13&qid=1640946230&sr=8-149
#
# Nillkin Case for Apple iPhone 13 (6.1" Inch) CamShield Silky Soft Liquid Silicon + PC Finish Camera Slider Inner Microfiber Black
# ₹3,999
#
#
# https://www.amazon.in/Nillkin-iPhone-CamShield-Silicon-Microfiber/dp/B09HXXB5R1/ref=sr_1_150?keywords=iphone+13&qid=1640946230&sr=8-150
#
# Lava Z3 Striped Cyan(3GB RAM, 32GB Storage)
# ₹7,299
# 4.1
# 36
# https://www.amazon.in/Lava-Striped-Cyan-32GB-Storage/dp/B09JG89LHZ/ref=sr_1_151?keywords=iphone+13&qid=1640946230&sr=8-151
#
# Nillkin Case for Apple iPhone 13 (6.1" Inch) CamShield Silky Soft Liquid Silicon + PC Finish Camera Slider Magnetic Works with Magsafe Charger Inside Microfibre Green
# ₹4,499
#
#
# https://www.amazon.in/Nillkin-CamShield-Silicon-Magnetic-Microfibre/dp/B09HXY1MXX/ref=sr_1_152?keywords=iphone+13&qid=1640946230&sr=8-152
#
# CellphoneMall Butterfly Love Flower Embossed Horizontal Flip Leather Case with Bracket/Card Slot/Wallet/Lanyard for iPhone 13 Pro
# ₹2,077.75
#
#
# https://www.amazon.in/CellphoneMall-Butterfly-Embossed-Horizontal-Leather/dp/B09NKQLFY2/ref=sr_1_153?keywords=iphone+13&qid=1640946230&sr=8-153
#
# CellphoneMall Mandala Embossed Cloth Cover PC + TPU Case with Magnetic Function and Hand Strap for iPhone 13 Pro
# ₹1,982.37
#
#
# https://www.amazon.in/CellphoneMall-Mandala-Embossed-Magnetic-Function/dp/B09N375N5R/ref=sr_1_154?keywords=iphone+13&qid=1640946230&sr=8-154
#
# Vivo V21e 5G (Dark Pearl, 8GB RAM, 128GB Storage) with No Cost EMI/Additional Exchange Offers
# ₹24,990
# 4.2
# 1,607
# https://www.amazon.in/Vivo-V21e-8GB-RAM-128GB/dp/B08ZMTJMLN/ref=sr_1_155?keywords=iphone+13&qid=1640946230&sr=8-155
#
# Jacure Design for iPhone 13 Pro Tempered Glass Back Side Rear Protector Proper Fit Bubble Free Case Friendly Easy Installation - White
# ₹499
#
#
# https://www.amazon.in/Jacure-iPhone-13-Pro-Installation/dp/B09P59P49N/ref=sr_1_156?keywords=iphone+13&qid=1640946230&sr=8-156
#
# Vivo Y33s (Middday Dream, 8GB RAM, 128GB Stoarge) with No Cost EMI/Additional Exchange Offers
# ₹18,990
# 4.2
# 815
# https://www.amazon.in/Vivo-Y33s-Middday-Additional-Exchange/dp/B08ZJRRLKC/ref=sr_1_157?keywords=iphone+13&qid=1640946230&sr=8-157
#
# CellphoneMall Imitated Mirror Surface Horizontal Flip Leather Case with Holder & Card Slots & Wallet & Lanyard for iPhone 13 Pro Max
# ₹2,160.68
#
#
# https://www.amazon.in/CellphoneMall-Imitated-Surface-Horizontal-Leather/dp/B09NLL7RGP/ref=sr_1_158?keywords=iphone+13&qid=1640946230&sr=8-158
#
# Tecno Camon 17 (Frost Silver, 6GB RAM, 128GB Storage)| 64MP Quad Camera | Professional Video| 17.27 cm (6.8") FHD
# ₹13,999
# 3.9
# 1,221
# https://www.amazon.in/Tecno-Silver-Storage-Camera-Professional/dp/B098SPF35L/ref=sr_1_159?keywords=iphone+13&qid=1640946230&sr=8-159
#
# CellphoneMall Multifunctional Phone Leather Case with Card Slot & Holder & Zipper Wallet & Photo Frame for iPhone 13 Pro
# ₹2,380.80
#
#
# https://www.amazon.in/CellphoneMall-Multifunctional-Leather-Holder-Zipper/dp/B09N37NH6W/ref=sr_1_160?keywords=iphone+13&qid=1640946230&sr=8-160
#
# Jacure Replacement with iPhone 13 Pro Max Privacy Screen Protector Matte Finish Soft Anti Glare Scratch Proof Bubble Free Ceramic Private Anti Spy Screen Cover for i13pro max - Black
# ₹699
#
#
# https://www.amazon.in/Jacure-Replacement-iPhone-Pro-Max/dp/B09LM44N57/ref=sr_1_161?keywords=iphone+13&qid=1640946232&sr=8-161
#
# CellphoneMall Shockproof PU Leather + TPU Protective Case with Card Slot & Lanyard for iPhone 13 Pro
# ₹2,251.38
#
#
# https://www.amazon.in/CellphoneMall-Shockproof-Leather-Protective-Lanyard/dp/B09MS1VR9Q/ref=sr_1_162?keywords=iphone+13&qid=1640946232&sr=8-162
#
# Xiaomi 11 Lite NE 5G (Tuscany Coral 6GB RAM 128 GB Storage) | Slimmest (6.81mm) & Lightest (158g) 5G Smartphone | 10-bit AMOLED with Dolby Vision | Additional Off up to 5000 on Exchange
# ₹26,999
# 4.2
# 6,214
# https://www.amazon.in/Xiaomi-Slimmest-Lightest-Smartphone-Additional/dp/B09G39YXFS/ref=sr_1_163?keywords=iphone+13&qid=1640946232&sr=8-163
#
# Nzon Compatible for iPhone 13 Pro Max Privacy Guard Soft Matte Finish Anti Glare Scratch Proof Bubble Free Ceramic Private Anti Spy Screen Protector for i13Pro Max Front Screen - Black
# ₹699
#
#
# https://www.amazon.in/Compatible-iPhone-13-Pro-Max/dp/B09LFBZZNR/ref=sr_1_164?keywords=iphone+13&qid=1640946232&sr=8-164
#
# CellphoneMall Four Corners Shocproof Flow Gold Marble IMD Back Cover Case for iPhone 13 Pro
# ₹2,047.77
#
#
# https://www.amazon.in/CellphoneMall-Corners-Shocproof-Marble-iPhone/dp/B09N381PN6/ref=sr_1_165?keywords=iphone+13&qid=1640946232&sr=8-165
#
# Vivo Y73 (Diamond Flare, 8GB RAM, 128GB Storage) with No Cost EMI/Additional Exchange Offers
# ₹20,990
# 4.4
# 1,042
# https://www.amazon.in/Vivo-Y73-8GB-RAM-128GB/dp/B08ZMVPYH6/ref=sr_1_166?keywords=iphone+13&qid=1640946232&sr=8-166
#
# CellphoneMall 3 in 1 Shockproof PC + Silicone Protective Case for iPhone 13 Pro Max
# ₹2,325.08
#
#
# https://www.amazon.in/CellphoneMall-Shockproof-Silicone-Protective-iPhone/dp/B09NLK41JR/ref=sr_1_167?keywords=iphone+13&qid=1640946232&sr=8-167
#
# Cascov (Camera Protection) Matte Case Cover for iPhone 13 - Black
# ₹299
#
#
# https://www.amazon.in/Cascov-Camera-Protection-iPhone-13/dp/B09N9JZHWQ/ref=sr_1_168?keywords=iphone+13&qid=1640946232&sr=8-168
#
# CellphoneMall Woven Texture Stitching Magnetic Horizontal Flip PU Leather Case with Holder & Card Slots & Wallet & Lanyard for iPhone 13 Pro Max
# ₹2,225.29
#
#
# https://www.amazon.in/CellphoneMall-Texture-Stitching-Magnetic-Horizontal/dp/B09NXL1SS5/ref=sr_1_169?keywords=iphone+13&qid=1640946232&sr=8-169
#
# MOTOROLA G40 Fusion (Dynamic Gray, 6 GB RAM, 128GB Storage)
# ₹16,990
# 3.7
# 24
# https://www.amazon.in/MOTOROLA-Fusion-Dynamic-128GB-Storage/dp/B09DG851NK/ref=sr_1_170?keywords=iphone+13&qid=1640946232&sr=8-170
#
# Samsung Galaxy F62 (Laser Grey, 6GB RAM, 128GB Storage)
# ₹23,999
# 3.9
# 354
# https://www.amazon.in/Samsung-Galaxy-Laser-128GB-Storage/dp/B0915TFJHN/ref=sr_1_171?keywords=iphone+13&qid=1640946232&sr=8-171
#
# New Apple iPhone 12 Mini (64GB) - Green with AirPods with Charging Case
# ₹71,899
# 4.7
# 30
# https://www.amazon.in/New-Apple-iPhone-Mini-64GB/dp/B08ZWGQ4J5/ref=sr_1_172?keywords=iphone+13&qid=1640946232&sr=8-172
#
# CellphoneMall Creative Shockproof Silicone TPU Protective Case with Wrist Bracelet Chain for iPhone 13
# ₹2,064.46
#
#
# https://www.amazon.in/CellphoneMall-Creative-Shockproof-Silicone-Protective/dp/B09NLMGG48/ref=sr_1_173?keywords=iphone+13&qid=1640946232&sr=8-173
#
# Vivo Y72 5G (Prism Magic, 8GB RAM, 128GB Storage) with No Cost EMI/Additional Exchange Offers
# ₹20,990
# 4.1
# 816
# https://www.amazon.in/Vivo-Y72-8GB-RAM-128GB/dp/B08ZMSWNSV/ref=sr_1_174?keywords=iphone+13&qid=1640946232&sr=8-174
#
# (Renewed) OnePlus 9 Pro 5G (Stellar Black, 12GB RAM, 256GB Storage)
# ₹58,299
# 3.
# 3
# https://www.amazon.in/Renewed-OnePlus-Stellar-Black-256GB-Storage/dp/B0968XH3T6/ref=sr_1_175?keywords=iphone+13&qid=1640946232&sr=8-175
#
# Cascov (Camera Protection) Matte Case Cover for iPhone 13 Pro - Blue
# ₹299
#
#
# https://www.amazon.in/Cascov-Protection-iPhone-13-Pro/dp/B09N9JJ7XM/ref=sr_1_176?keywords=iphone+13&qid=1640946232&sr=8-176
#
# Samsung Galaxy Z Fold2 5G Mystic Bronze, 12GB RAM, 256GB Storage
# ₹1,34,999
# 4.6
# 122
# ...
# ₹2,160.48
#
#
# https://www.amazon.in/CellphoneMall-Flowers-Embossing-Magnetic-Horizontal/dp/B09MS3HTKS/ref=sr_1_237?keywords=iphone+13&qid=1640946241&sr=8-237
#
# Jacure Replacement for iPhone 13/13 Pro Matte Finish Ceramic Screen Protector Flexible Film TPU Screen Protector for iPhone 13 Pro 6.1 Inch [Case Friendly] [Full Coverage] - Black
# ₹199
#
#
# https://www.amazon.in/Jacure-Replacement-iPhone-13-Pro/dp/B09MD5PTGN/ref=sr_1_238?keywords=iphone+13&qid=1640946241&sr=8-238
#
# Samsung Galaxy A52s 5G (White, 6GB RAM, 128GB Storage) with No Cost EMI/Additional Exchange Offers
# ₹35,999
# 4.2
# 1,111
# https://www.amazon.in/Samsung-Galaxy-Storage-Additional-Exchange/dp/B09D87CW32/ref=sr_1_239?keywords=iphone+13&qid=1640946241&sr=8-239
#
# Lava Agni 5G Fiery Blue (8GB RAM, 128GB Storage)
# ₹19,999
# 4.4
# 63
# https://www.amazon.in/Lava-Agni-Fiery-128GB-Storage/dp/B09JW2KPRM/ref=sr_1_241?keywords=iphone+13&qid=1640946243&sr=8-241
#
# Nillkin Case for Apple iPhone 12 Pro Max (6.7" Inch) CamShield Silky Soft Liquid Silicon + PC Finish Camera Close & Open Inner Microfiber Lining Pink
# ₹3,999
#
#
# https://www.amazon.in/Nillkin-iPhone-CamShield-Silicon-Microfiber/dp/B093LMB5BX/ref=sr_1_242?keywords=iphone+13&qid=1640946243&sr=8-242
#
# CellphoneMall Silicone Wallet Pouch Card Case Magsng Card Holder for iPhone 13 Series/iPhone 12 Series
# ₹2,771.99
#
#
# https://www.amazon.in/dp/B09PFTC8VT/ref=sr_1_243?keywords=iphone+13&qid=1640946243&sr=8-243
#
# Vivo Y1s (Aurora Blue, 3GB RAM, 32GB Storage) with No Cost EMI/Additional Exchange Offers
# ₹9,490
# 4.2
# 470
# https://www.amazon.in/Vivo-Y1s-3GB-RAM-32GB/dp/B08ZMSF139/ref=sr_1_244?keywords=iphone+13&qid=1640946243&sr=8-244
#
# CellphoneMall Candy Transparent Phone Case with Lanyard for iPhone 13 Pro Max
# ₹2,036.43
#
#
# https://www.amazon.in/CellphoneMall-Candy-Transparent-Lanyard-iPhone/dp/B09NLMY3CW/ref=sr_1_245?keywords=iphone+13&qid=1640946243&sr=8-245
#
# Glaslux Dazzle Kickstand Hybrid Desk Stand Back Case Cover for iPhone 13 - Black
# ₹299
#
#
# https://www.amazon.in/Glaslux-Dazzle-Kickstand-iPhone-13/dp/B09M8Y9K4G/ref=sr_1_246?keywords=iphone+13&qid=1640946243&sr=8-246
#
# Zivite iPhone 13 Kickstand Hybrid Desk Stand Back Case Cover for iPhone 13 - Black
# ₹299
#
#
# https://www.amazon.in/Zivite-iPhone-13-Kickstand-Hybrid/dp/B09M8Q2Z6Y/ref=sr_1_247?keywords=iphone+13&qid=1640946243&sr=8-247
#
# CellphoneMall Pressed Printing Sunflower Pattern Horizontal Flip PU Leather Case Holder & Card Slots & Wallet & Lanyard for iPhone 13 Pro Max
# ₹2,062.28
#
#
# https://www.amazon.in/CellphoneMall-Pressed-Printing-Sunflower-Horizontal/dp/B09NX6CM9X/ref=sr_1_248?keywords=iphone+13&qid=1640946243&sr=8-248
#
# Vivo X50 Pro (Alpha Grey, 8GB RAM, 256GB Storage) with No Cost EMI/Additional Exchange Offers
# ₹39,999
# 4.
# 548
# https://www.amazon.in/Vivo-Storage-Additional-Exchange-Offers/dp/B089MRYGSV/ref=sr_1_249?keywords=iphone+13&qid=1640946243&sr=8-249
#
# Vivo Y20G 2021 (Obsidiant Black, 4GB RAM, 64GB Storage) with No Cost EMI/Additional Exchange Offers
# ₹13,990
# 4.2
# 782
# https://www.amazon.in/Vivo-Y20G-2021-4GB-64GB/dp/B08ZMT9MQV/ref=sr_1_250?keywords=iphone+13&qid=1640946243&sr=8-250
#
# (Renewed) Mi 11X Pro 5G (Cosmic Black, 8GB RAM, 128GB Storage) | Snapdragon 888 | 108MP Camera
# ₹30,499
#
#
# https://www.amazon.in/Renewed-Mi-11X-Storage-Snapdragon/dp/B099TKQZHJ/ref=sr_1_251?keywords=iphone+13&qid=1640946243&sr=8-251
#
# Nzon Design for iPhone 13 Mini Screen Protector Guard Premium Membrane [Works with Fingerprint Scanner] Anti-Bubble Clear Film Screen Protector - Clear
# ₹399
#
#
# https://www.amazon.in/iPhone-13-Mini-Fingerprint-Anti-Bubble/dp/B09LRFB2QY/ref=sr_1_252?keywords=iphone+13&qid=1640946243&sr=8-252
#
# CellphoneMall Y Style Multifunction Card Stand Back Cover PU + TPU + PC Magnetic Shockproof Case for iPhone 13
# ₹2,079.93
#
#
# https://www.amazon.in/dp/B09PFZ65SM/ref=sr_1_253?keywords=iphone+13&qid=1640946243&sr=8-253
#
# CellphoneMall Elastic Silicone Protective Case with Wide Neck Lanyard for iPhone 13 Pro Max
# ₹2,209.69
#
#
# https://www.amazon.in/dp/B09PFTRRR2/ref=sr_1_254?keywords=iphone+13&qid=1640946243&sr=8-254
#
# CellphoneMall Zipper Bag PU + TPU Horizontal Flip Leather Case with Holder & Card Slot & Wallet & Lanyard for iPhone 13
# ₹2,337.22
#
#
# https://www.amazon.in/dp/B09PFSRBY9/ref=sr_1_255?keywords=iphone+13&qid=1640946243&sr=8-255
#
# CellphoneMall Texture PU + PC Protective Case with Card Slots for iPhone 13 Pro Max
# ₹2,182.10
#
#
# https://www.amazon.in/dp/B09PFSP1NX/ref=sr_1_256?keywords=iphone+13&qid=1640946243&sr=8-256
#
# CellphoneMall for iPhone 13 Four Corners Shocproof Flow Gold Marble IMD Back Cover Case with Metal Rhinestone Ring
# ₹2,209.69
#
#
# https://www.amazon.in/dp/B09PFSKSR2/ref=sr_1_257?keywords=iphone+13&qid=1640946246&sr=8-257
#
# CellphoneMall Frosted Business Magnetic Horizontal Flip PU Leather Case with Holder & Card Slot & Lanyard for iPhone 13
# ₹2,053.08
#
#
# https://www.amazon.in/dp/B09PFSJNYG/ref=sr_1_258?keywords=iphone+13&qid=1640946246&sr=8-258
#
# CellphoneMall Multifunctional Texture Horizontal Flip Leather Case with 9 Card Slot & Holder & Zipper Wallet & Lanyard for iPhone 13
# ₹2,332.74
#
#
# https://www.amazon.in/dp/B09PFSJJ1P/ref=sr_1_259?keywords=iphone+13&qid=1640946246&sr=8-259
#
# CellphoneMall Supersonic PC + TPU Shock-Proof Protective Case with Holder for iPhone 13 Pro Max
# ₹2,003.12
#
#
# https://www.amazon.in/dp/B09PFSDNBF/ref=sr_1_260?keywords=iphone+13&qid=1640946246&sr=8-260
#
# CellphoneMall Accurate Hole Braided Nylon Heat Dissipation PC + TPU Protective Case for iPhone 13 Pro Max
# ₹2,047.86
#
#
# https://www.amazon.in/dp/B09PFSD3N2/ref=sr_1_261?keywords=iphone+13&qid=1640946246&sr=8-261
#
# CellphoneMall Color Contrast Lens Frame Transparent TPU Phone Case for iPhone 13
# ₹1,888.27
#
#
# https://www.amazon.in/dp/B09PFS9FNX/ref=sr_1_262?keywords=iphone+13&qid=1640946246&sr=8-262
#
# CellphoneMall Acrylic Hollow Out Phone Case with Lanyard for iPhone 13 Pro Max
# ₹2,062.78
#
#
# https://www.amazon.in/dp/B09PFS8SDM/ref=sr_1_263?keywords=iphone+13&qid=1640946246&sr=8-263
#
# CellphoneMall Dream PU+TPU Four-Corner Shockproof Back Cover Case with Card Slots & Holder for iPhone 13
# ₹2,079.93
#
#
# https://www.amazon.in/CellphoneMall-Four-Corner-Shockproof-Holder-iPhone/dp/B09PFS7VFG/ref=sr_1_264?keywords=iphone+13&qid=1640946246&sr=8-264
#
# CellphoneMall Cloth Texture PC + PU Leather Back Cover Shockproof Case with Card Slot for iPhone 13
# ₹2,098.57
#
#
# https://www.amazon.in/CellphoneMall-Texture-Leather-Shockproof-iPhone/dp/B09PFS7RBL/ref=sr_1_265?keywords=iphone+13&qid=1640946246&sr=8-265
#
# CellphoneMall Black Lens Frame Transparent TPU Phone Case for iPhone 13
# ₹1,888.27
#
#
# https://www.amazon.in/dp/B09PFS7B6P/ref=sr_1_266?keywords=iphone+13&qid=1640946246&sr=8-266
#
# CellphoneMall Stitching Style 2-Color Cow Texture Horizontal Flip PU Leather Case with Holder & Card Slot & Lanyard for iPhone 13 Pro Max
# ₹2,062.03
#
#
# https://www.amazon.in/dp/B09PFS6VLD/ref=sr_1_267?keywords=iphone+13&qid=1640946246&sr=8-267
#
# CellphoneMall Mandala Flower Embossed Horizontal Flip Leather Case with Holder & Three Card Slots & Wallet& Lanyard for iPhone 13 Pro Max
# ₹2,047.86
#
#
# https://www.amazon.in/dp/B09PFS5W2X/ref=sr_1_268?keywords=iphone+13&qid=1640946246&sr=8-268
#
# CellphoneMall Gradient Glitter Powder Epoxy TPU Thickened Acrylic Shockproof Case with Wide Neck Lanyard for iPhone 13 Pro Max
# ₹2,249.22
#
#
# https://www.amazon.in/dp/B09PFS4Y8K/ref=sr_1_269?keywords=iphone+13&qid=1640946246&sr=8-269
#
# CellphoneMall for iPhone 13 Pro Max Retro Lambskin Texture Pure Color Horizontal Flip PU Leather Case, with Holder & Card Slots & Wallet & Lanyard
# ₹1,996.40
#
#
# https://www.amazon.in/dp/B09PFS3M57/ref=sr_1_270?keywords=iphone+13&qid=1640946246&sr=8-270
#
# CellphoneMall Stitching Style 2-Color Cow Texture Horizontal Flip PU Leather Case with Holder & Card Slot & Lanyard for iPhone 13
# ₹2,062.03
#
#
# https://www.amazon.in/CellphoneMall-Stitching-2-Color-Texture-Horizontal/dp/B09PFS2TXL/ref=sr_1_271?keywords=iphone+13&qid=1640946246&sr=8-271
#
# CellphoneMall Lace Pattern Double Button Zipper Horizontal Flip Leather Case with Holder & Card Slots & Wallet for iPhone 13
# ₹2,255.93
#
#
# https://www.amazon.in/dp/B09PFS2FR8/ref=sr_1_272?keywords=iphone+13&qid=1640946246&sr=8-272
#
# CellphoneMall TPU + PC Anti-Gravity Dropproof Protective Back Cover for iPhone 13
# ₹2,094.10
#
#
# https://www.amazon.in/CellphoneMall-Anti-Gravity-Dropproof-Protective-iPhone/dp/B09PFS26GV/ref=sr_1_273?keywords=iphone+13&qid=1640946250&sr=8-273
#
# CellphoneMall Shockproof Waterproof Dustproof Metal + Silicone Phone Case with Screen Protector for iPhone 13
# ₹4,083.79
#
#
# https://www.amazon.in/dp/B09PFS1PNB/ref=sr_1_274?keywords=iphone+13&qid=1640946250&sr=8-274
#
# CellphoneMall Mandala Embossed PU + TPU Case with Holder & Card Slots & Photo Frame & Hand Strap for iPhone 13
# ₹2,240.27
#
#
# https://www.amazon.in/CellphoneMall-Mandala-Embossed-Holder-iPhone/dp/B09PFRZSDW/ref=sr_1_275?keywords=iphone+13&qid=1640946250&sr=8-275
#
# CellphoneMall Frosted Soft Four-Corner Shockproof Case with Finger Ring Strap & Metal Lens Cover for iPhone 13 Pro Max
# ₹1,887.52
#
#
# https://www.amazon.in/dp/B09PFRZPJ7/ref=sr_1_276?keywords=iphone+13&qid=1640946250&sr=8-276
#
# CellphoneMall Wheat Straw Material + TPU Shockproof Case with Neck Lanyard for iPhone 13 Pro Max
# ₹2,126.91
#
#
# https://www.amazon.in/dp/B09PFRZGPF/ref=sr_1_277?keywords=iphone+13&qid=1640946250&sr=8-277
#
# CellphoneMall Crossbody Wallet Card Bag Phone Case for iPhone 13
# ₹2,436.40
#
#
# https://www.amazon.in/CellphoneMall-Crossbody-Wallet-Phone-iPhone/dp/B09PFRZ5JP/ref=sr_1_278?keywords=iphone+13&qid=1640946250&sr=8-278
#
# CellphoneMall Robot Shockproof Silicone + PC Protective Case with Back Clip Holder for iPhone 13 Pro Max
# ₹2,207.45
#
#
# https://www.amazon.in/dp/B09PFRZ1H4/ref=sr_1_279?keywords=iphone+13&qid=1640946250&sr=8-279
#
# CellphoneMall for iPhone 13 Pro Max Side Window Display Magnetic Suction Plain Grain Flip PU Leather + PC Case with Holder
# ₹2,208.20
#
#
# https://www.amazon.in/dp/B09PFRYKGT/ref=sr_1_280?keywords=iphone+13&qid=1640946250&sr=8-280
#
# CellphoneMall Shockproof TPU + Double-Sided Glass Protective Case for iPhone 13 Pro Max
# ₹2,482.64
#
#
# https://www.amazon.in/dp/B09PFRXBZ5/ref=sr_1_281?keywords=iphone+13&qid=1640946250&sr=8-281
#
# CellphoneMall Wristband Phone Case for iPhone 13
# ₹2,161.22
#
#
# https://www.amazon.in/CellphoneMall-Wristband-Phone-Case-iPhone/dp/B09PFRTX3L/ref=sr_1_282?keywords=iphone+13&qid=1640946250&sr=8-282
#
# CellphoneMall Sliding Camera Cover Design Precise Hole TPU+PC Protective Case for iPhone 13
# ₹1,936.74
#
#
# https://www.amazon.in/dp/B09PFRT8N4/ref=sr_1_283?keywords=iphone+13&qid=1640946250&sr=8-283
#
# CellphoneMall Solid Silicone Phone Case for iPhone 13
# ₹1,904.68
#
#
# https://www.amazon.in/CellphoneMall-Solid-Silicone-Phone-iPhone/dp/B09PFRNTPF/ref=sr_1_284?keywords=iphone+13&qid=1640946250&sr=8-284
#
# CellphoneMall Paste Skin + PC Thermal Sensor Discoloration Case for iPhone 13 Pro Max
# ₹2,001.62
#
#
# https://www.amazon.in/dp/B09PFRN6SY/ref=sr_1_285?keywords=iphone+13&qid=1640946250&sr=8-285
#
# CellphoneMall Electroplating Lambskin Lanyard Phone Case for iPhone 13
# ₹2,033.69
#
#
# https://www.amazon.in/dp/B09PFRHYC6/ref=sr_1_286?keywords=iphone+13&qid=1640946250&sr=8-286
#
# CellphoneMall Litchi Texture Genuine Leather Phone Case with Lanyard & Holder & Card Slots & Wallet for iPhone 13
# ₹2,930.84
#
#
# https://www.amazon.in/CellphoneMall-Texture-Genuine-Leather-Lanyard/dp/B09PFRHVBY/ref=sr_1_287?keywords=iphone+13&qid=1640946250&sr=8-287
#
# CellphoneMall Texture Buckle Horizontal Flip Leather Case with Holder & Card Slots & Wallet for iPhone 13
# ₹2,450.57
#
#
# https://www.amazon.in/dp/B09PFRGPPN/ref=sr_1_288?keywords=iphone+13&qid=1640946250&sr=8-288
#
# CellphoneMall Leopard Crossbody Shockproof TPU Phone Case with Lanyard for iPhone 13 Pro Max
# ₹2,085.15
#
#
# https://www.amazon.in/dp/B09PFRCD8Z/ref=sr_1_289?keywords=iphone+13&qid=1640946253&sr=8-289
#
# CellphoneMall High Transparent Tempered Glass + TPU Shockproof Case for iPhone 13 Pro Max
# ₹2,001.62
#
#
# https://www.amazon.in/dp/B09PFR55N9/ref=sr_1_290?keywords=iphone+13&qid=1640946253&sr=8-290
#
# CellphoneMall Sliding Camshield Holder Phone Case for iPhone 13 Pro Max
# ₹2,011.18
#
#
# https://www.amazon.in/CellphoneMall-Sliding-Camshield-Holder-iPhone/dp/B09PBBR3GV/ref=sr_1_291?keywords=iphone+13&qid=1640946253&sr=8-291
#
# CellphoneMall Shockproof TPU + Single-Sided Glass Protective Case for iPhone 13 Pro Max
# ₹2,044.91
#
#
# https://www.amazon.in/CellphoneMall-Shockproof-Single-Sided-Protective-iPhone/dp/B09PBBK4LJ/ref=sr_1_292?keywords=iphone+13&qid=1640946253&sr=8-292
#
# CellphoneMall PC + Rubber 3-Layers Shockproof Protective Case with Rotating Holder for iPhone 13 Pro Max
# ₹2,194.08
#
#
# https://www.amazon.in/CellphoneMall-3-Layers-Shockproof-Protective-Rotating/dp/B09PBB9QR3/ref=sr_1_293?keywords=iphone+13&qid=1640946253&sr=8-293
#
# CellphoneMall Ring Holder Non-Slip Phone Case for iPhone 13 Pro Max
# ₹2,065.90
#
#
# https://www.amazon.in/CellphoneMall-Holder-Non-Slip-Phone-iPhone/dp/B09PB9W71M/ref=sr_1_294?keywords=iphone+13&qid=1640946253&sr=8-294
#
# CellphoneMall Electroplated TPU Pattern Leather Case with Wrist Strap for iPhone 13 Pro Max
# ₹2,220.32
#
#
# https://www.amazon.in/CellphoneMall-Electroplated-Pattern-Leather-iPhone/dp/B09PB9S5PW/ref=sr_1_295?keywords=iphone+13&qid=1640946253&sr=8-295
#
# CellphoneMall 9H Point Drill Camera Lens Protector Circle for iPhone 13 Pro Max / 13 Pro
# ₹2,107.88
#
#
# https://www.amazon.in/CellphoneMall-Camera-Protector-Circle-iPhone/dp/B09PB9LJWZ/ref=sr_1_296?keywords=iphone+13&qid=1640946253&sr=8-296
#
# CellphoneMall Acrylic + Color TPU Shockproof Case with Neck Lanyard for iPhone 13 Pro Max
# ₹2,006.68
#
#
# https://www.amazon.in/CellphoneMall-Acrylic-Shockproof-Lanyard-iPhone/dp/B09PB9L4C8/ref=sr_1_297?keywords=iphone+13&qid=1640946253&sr=8-297
#
# CellphoneMall Texture Horizontal Flip Leather Case with Holder & Card Slots & Lanyard for iPhone 13 Pro Max
# ₹2,071.15
#
#
# https://www.amazon.in/CellphoneMall-Texture-Horizontal-Leather-Lanyard/dp/B09PB9K3ZJ/ref=sr_1_298?keywords=iphone+13&qid=1640946253&sr=8-298
#
# CellphoneMall Lanyard Aluminum TPU Case for iPhone 13 Pro Max
# ₹2,106.38
#
#
# https://www.amazon.in/CellphoneMall-Lanyard-Aluminum-Case-iPhone/dp/B09PB9J7G3/ref=sr_1_299?keywords=iphone+13&qid=1640946253&sr=8-299
#
# CellphoneMall Antelope Texture Magnetic Buckle Horizontal Flip PU Leather Case with Card Slots & Wallet & Holder for iPhone 13 Pro Max
# ₹2,266.80
#
#
# https://www.amazon.in/CellphoneMall-Antelope-Texture-Magnetic-Horizontal/dp/B09PB9DT5Y/ref=sr_1_300?keywords=iphone+13&qid=1640946253&sr=8-300
#
# CellphoneMall IMD Pattern TPU Protective Case for iPhone 13 Pro Max
# ₹2,092.89
#
#
# https://www.amazon.in/CellphoneMall-Pattern-Protective-Case-iPhone/dp/B09PB8WBNK/ref=sr_1_301?keywords=iphone+13&qid=1640946253&sr=8-301
#
# CellphoneMall Skin-Feel Texture Zipper Wallet Bag Horizontal Flip Leather Case with Holder & Card Slots & Wallet & Lanyard for iPhone 13 Pro Max
# ₹2,396.48
#
#
# https://www.amazon.in/CellphoneMall-Skin-Feel-Texture-Horizontal-Leather/dp/B09PB8RTW2/ref=sr_1_302?keywords=iphone+13&qid=1640946253&sr=8-302
#
# CellphoneMall Skin Feel Life Tree Metal Button Horizontal Flip Leather Case with Holder & Card Slot & Wallet & Photo Frame & Strap for iPhone 13 Pro Max
# ₹2,127.37
#
#
# https://www.amazon.in/CellphoneMall-Button-Horizontal-Leather-Holder/dp/B09PB8QDKN/ref=sr_1_303?keywords=iphone+13&qid=1640946253&sr=8-303
#
# CellphoneMall Life of Tree Embossing Pattern Horizontal Flip Leather Case with Holder & Card Slot & Wallet & Photo Frame & Lanyard for iPhone 13 Pro Max
# ₹2,136.36
#
#
# https://www.amazon.in/CellphoneMall-Embossing-Pattern-Horizontal-Leather/dp/B09PB8C96L/ref=sr_1_304?keywords=iphone+13&qid=1640946253&sr=8-304
#
# CellphoneMall Texture Leather Horizontal Flip Protective Case with Holder & Card Slots & Wallet & Photo Frame for iPhone 13 Pro Max
# ₹2,028.42
#
#
# https://www.amazon.in/CellphoneMall-Texture-Leather-Horizontal-Protective/dp/B09PB85NRX/ref=sr_1_305?keywords=iphone+13&qid=1640946257&sr=8-305
#
# (Renewed) OnePlus 9 Pro 5G (Pine Green, 8GB RAM, 128GB Storage)
# ₹54,399
# 3.0
# 2
# https://www.amazon.in/Renewed-OnePlus-Pine-Green-128GB-Storage/dp/B0968YBGLP/ref=sr_1_306?keywords=iphone+13&qid=1640946257&sr=8-306

# %% [markdown]
# ## Formulate a Function for Creating a Spreadsheet with Product Information

# %% [markdown]
# A function is created for writing information of all products into a CSV file.

# %%
# Function for generating CSV file with product information
def generate_csv(search_input, product_info):
    search_input_mod = search_input.replace(' ', '_')
    current_datetime = datetime.now().strftime("%y%m%d%H%M%S")
    filename = search_input_mod + '_' + current_datetime + '.csv'
    
    with open(filename, 'w', newline = '', encoding = 'utf-8') as file:
        writer = csv.writer(file)
        writer.writerow(['Product Name', 'Price (In Rupees)', 'Rating (Out of 5)', 'No. of Reviews', 'Product Link'])
        writer.writerows(product_info)
        print("Product info has been written to " + filename)

# %% [markdown]
# ## Create Final Code

# %% [markdown]
# The last step is to put together all the components and build the final version of the code

# %%
# For webscraping
from bs4 import BeautifulSoup
# Chrome driver
from selenium import webdriver
# Chrome driver manager
from webdriver_manager.chrome import ChromeDriverManager
# For current data and time
from datetime import datetime
# For writing results to CSV file
import csv

# Function for generating CSV file with product information
def generate_csv(search_input, product_info):
    search_input_mod = search_input.replace(' ', '_')
    current_datetime = datetime.now().strftime("%y%m%d%H%M%S")
    filename = search_input_mod + '_' + current_datetime + '.csv'
    
    with open(filename, 'w', newline = '', encoding = 'utf-8') as file:
        writer = csv.writer(file)
        writer.writerow(['Product Name', 'Price', 'Rating (Out of 5)', 'No. of Reviews', 'Product Link'])
        writer.writerows(product_info)
        print("Product info has been written to " + filename)

# Function for generating URL based on user search input
def get_url(search_input):
    search_input_mod = search_input.replace(' ', '+')
    url = 'https://www.amazon.in/s?k=' + search_input_mod
    return url

# Function for extracting product data with exception handling
def extract_data(product):
    
    try:
        name = product.h2.a.text.strip()
        price = product.find('span', 'a-price-whole').text
        link = 'https://www.amazon.in' + product.h2.a.get('href')
    except:
        return
    
    try: 
        ratings = product.find('span', 'a-icon-alt').text.strip(' out of 5 stars')
        num_of_reviews = product.find('span', 'a-size-base').text
    except:
        ratings = ''
        num_of_reviews = ''
    
    info = (name, price, ratings, num_of_reviews, link)
    return info

def main():
    # Run main program
    # Initialize webdriver for chrome
    driver = webdriver.Chrome(ChromeDriverManager().install())

    print('________________________')
    print('AMAZON.IN SEARCH RESULTS')
    print('************************')
    print('This program exports the')
    print('results of user search')
    print('query into a CSV file')

    continue_search = True

    while continue_search:
        product_info = []

        search_input = input('\nSearch for: ')
        url = get_url(search_input)

        # To get product data in each page of 20 pages long search result
        for page_num in range(1, 21):
            url_full = url + '&page=' + str(page_num)
            driver.get(url_full)
            soup = BeautifulSoup(driver.page_source, 'html.parser')
    
            product_data = soup.find_all('div', {'data-component-type': 's-search-result'})
            for product in product_data:
                info = extract_data(product)
                if info:
                    product_info.append(info)

        generate_csv(search_input, product_info)

        while True:
            continue_response = input('\nWould you like to search again? (Y/N): ')
            if continue_response.lower() == 'y':
                continue_search = True
                break
            elif continue_response.lower() == 'n':
                continue_search = False
                break
            else:
                print("Enter a valid response.")
                continue

if __name__ == "__main__":
    main()
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 96.0.4664
# Get LATEST chromedriver version for 96.0.4664 google-chrome
# Driver [C:\Users\iammi\.wdm\drivers\chromedriver\win32\96.0.4664.45\chromedriver.exe] found in cache
# C:\Users\iammi\AppData\Local\Temp/ipykernel_11008/1461561201.py:53: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install())
# ________________________
# AMAZON.IN SEARCH RESULTS
# ************************
# This program exports the
# results of user search
# query into a CSV file
#
# Search for: samsung galaxy
# Product info has been written to samsung_galaxy_211231161246.csv
#
# Would you like to search again? (Y/N): y
#
# Search for: oneplus nord 2
# Product info has been written to oneplus_nord_2_211231161331.csv
#
# Would you like to search again? (Y/N): n
